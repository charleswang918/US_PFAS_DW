# %%
import pandas as pd
import os
import numpy as np

# %%
os.getcwd()
# Out:
# '/Users/chuqiwang/Documents/US_PFAS_Project/data_cleaning/Georgia'

# %%
ga_df1 = pd.read_excel('Export_Moody AFB.xlsx')

# %%
ga_df1
# Out:
#      Component ID  Component    State Installation Name Installation Type  \
# 0            5700  Air Force  Georgia         Moody AFB            Active
# 1            5700  Air Force  Georgia         Moody AFB            Active
# 2            5700  Air Force  Georgia         Moody AFB            Active
# 3            5700  Air Force  Georgia         Moody AFB            Active
# 4            5700  Air Force  Georgia         Moody AFB            Active
# ..            ...        ...      ...               ...               ...
# 139          5700  Air Force  Georgia         Moody AFB            Active
# 140          5700  Air Force  Georgia         Moody AFB            Active
# 141          5700  Air Force  Georgia         Moody AFB            Active
# 142          5700  Air Force  Georgia         Moody AFB            Active
# 143          5700  Air Force  Georgia         Moody AFB            Active
#
#     Lab Report Id Laboratory Sample ID Sample Date Analysis Method  \
# 0         FA93251            FA93251-1   2/15/2022         QSM_B15
# 1         FA93251            FA93251-1   2/15/2022         QSM_B15
# 2         FA93251            FA93251-1   2/15/2022         QSM_B15
# 3         FA93251            FA93251-1   2/15/2022         QSM_B15
# 4         FA93251            FA93251-1   2/15/2022         QSM_B15
# ..            ...                  ...         ...             ...
# 139       FA93250            FA93250-3   2/15/2022         QSM_B15
# 140       FA93250            FA93250-3   2/15/2022         QSM_B15
# 141       FA93250            FA93250-3   2/15/2022         QSM_B15
# 142       FA93250            FA93250-3   2/15/2022         QSM_B15
# 143       FA93250            FA93250-3   2/15/2022         QSM_B15
#
#       CAS Number Analyte Abbreviation  Final Result  Limit of Detection  \
# 0    757124-72-4               4:2FTS           NaN                   8
# 1     27619-97-2               6:2FTS           NaN                   8
# 2     39108-34-4               8:2FTS           NaN                   8
# 3      2991-50-6             NEtFOSAA           NaN                   8
# 4      2355-31-9             NMeFOSAA           NaN                   8
# ..           ...                  ...           ...                 ...
# 139    2706-91-4                PFPeS           3.6                   4
# 140    2706-90-3                PFPeA          12.9                   4
# 141     376-06-7               PFTeDA           NaN                   4
# 142   72629-94-8               PFTrDA           NaN                   4
# 143    2058-94-8                PFUnA           NaN                   4
#
#     Final Units Final Qualification Treatment System  Pre Or Post Treatment
# 0          ng/L                   U               No                    NaN
# 1          ng/L                   U               No                    NaN
# 2          ng/L                   U               No                    NaN
# 3          ng/L                   U               No                    NaN
# 4          ng/L                   U               No                    NaN
# ..          ...                 ...              ...                    ...
# 139        ng/L                   J               No                    NaN
# 140        ng/L                 NaN               No                    NaN
# 141        ng/L                   U               No                    NaN
# 142        ng/L                   U               No                    NaN
# 143        ng/L                   U               No                    NaN
#
# [144 rows x 17 columns]

# %%
columns = {
    'sample_id': str,
    'sampling_location': str,
    'data_source': str,
    'latitude': float,
    'longitude': float,
    'sampling_date': 'datetime64[ns]',
    'pws_id': str,
    'water_system_name': str,
    'population': int,
    'well_type': str,
    'well_depth': float,
    'units': str,
    'source_type': str,
    'state': str,
    'city': str,
    'county': str,
    'MRL': float,
    'DL': float,
    'analytical_methods': str,
    'is_detected': bool,
    'analyte': str,
    'concentration': float,
    'pfas_total': float,
    'note': str   
}

# %%
df1 = pd.DataFrame({col: pd.Series(dtype=dt) for col, dt in columns.items()})

# %%
df1['analyte'] = ga_df1['Analyte Abbreviation'].str.upper()
df1['concentration'] = ga_df1['Final Result'].fillna(0)
df1['sampling_location'] = ga_df1['Installation Name']
df1['DL'] = ga_df1['Limit of Detection']
df1['sampling_date'] = pd.to_datetime(ga_df1['Sample Date'])
df1['sample_id'] = ga_df1['Laboratory Sample ID']
df1['units'] = ga_df1['Final Units']
df1['state'] = ga_df1['State']
df1['analytical_methods'] = ga_df1['Analysis Method']
df1['data_source'] = 'DoD'
df1['source_type'] = 'drinking water'

# %%
df1['is_detected'] = df1['concentration'] != 0

# %%
df1
# Out:
#      sample_id sampling_location data_source  latitude  longitude  \
# 0    FA93251-1         Moody AFB         DoD       NaN        NaN
# 1    FA93251-1         Moody AFB         DoD       NaN        NaN
# 2    FA93251-1         Moody AFB         DoD       NaN        NaN
# 3    FA93251-1         Moody AFB         DoD       NaN        NaN
# 4    FA93251-1         Moody AFB         DoD       NaN        NaN
# ..         ...               ...         ...       ...        ...
# 139  FA93250-3         Moody AFB         DoD       NaN        NaN
# 140  FA93250-3         Moody AFB         DoD       NaN        NaN
# 141  FA93250-3         Moody AFB         DoD       NaN        NaN
# 142  FA93250-3         Moody AFB         DoD       NaN        NaN
# 143  FA93250-3         Moody AFB         DoD       NaN        NaN
#
#     sampling_date pws_id water_system_name  population well_type  ...  city  \
# 0      2022-02-15    NaN               NaN         NaN       NaN  ...   NaN
# 1      2022-02-15    NaN               NaN         NaN       NaN  ...   NaN
# 2      2022-02-15    NaN               NaN         NaN       NaN  ...   NaN
# 3      2022-02-15    NaN               NaN         NaN       NaN  ...   NaN
# 4      2022-02-15    NaN               NaN         NaN       NaN  ...   NaN
# ..            ...    ...               ...         ...       ...  ...   ...
# 139    2022-02-15    NaN               NaN         NaN       NaN  ...   NaN
# 140    2022-02-15    NaN               NaN         NaN       NaN  ...   NaN
# 141    2022-02-15    NaN               NaN         NaN       NaN  ...   NaN
# 142    2022-02-15    NaN               NaN         NaN       NaN  ...   NaN
# 143    2022-02-15    NaN               NaN         NaN       NaN  ...   NaN
#
#     county MRL DL analytical_methods is_detected   analyte  concentration  \
# 0      NaN NaN  8            QSM_B15       False    4:2FTS            0.0
# 1      NaN NaN  8            QSM_B15       False    6:2FTS            0.0
# 2      NaN NaN  8            QSM_B15       False    8:2FTS            0.0
# 3      NaN NaN  8            QSM_B15       False  NETFOSAA            0.0
# 4      NaN NaN  8            QSM_B15       False  NMEFOSAA            0.0
# ..     ...  .. ..                ...         ...       ...            ...
# 139    NaN NaN  4            QSM_B15        True     PFPES            3.6
# 140    NaN NaN  4            QSM_B15        True     PFPEA           12.9
# 141    NaN NaN  4            QSM_B15       False    PFTEDA            0.0
# 142    NaN NaN  4            QSM_B15       False    PFTRDA            0.0
# 143    NaN NaN  4            QSM_B15       False     PFUNA            0.0
#
#     pfas_total  note
# 0          NaN   NaN
# 1          NaN   NaN
# 2          NaN   NaN
# 3          NaN   NaN
# 4          NaN   NaN
# ..         ...   ...
# 139        NaN   NaN
# 140        NaN   NaN
# 141        NaN   NaN
# 142        NaN   NaN
# 143        NaN   NaN
#
# [144 rows x 24 columns]

# %%
df = df1

# %%
from concurrent.futures import ThreadPoolExecutor
import pandas as pd
from geopy.geocoders import OpenCage

geolocator = OpenCage(api_key="c7f16120befe4e3fb85e7a082e620fdb")

def geocode_address(address):
    try:
        location = geolocator.geocode(address)
        if location:
            return (address, location.latitude, location.longitude)
        else:
            return (address, None, None)
    except Exception as e:
        print(f"Error geocoding {address}: {e}")
        return (address, None, None)

# 假设 df 是您的数据框，以下是改进的代码
# 只提取需要查询的地址
addresses_to_query = df.loc[df['latitude'].isna() | df['longitude'].isna(), 'sampling_location'].unique()

# 用多线程处理查询任务
with ThreadPoolExecutor(max_workers=10) as executor:
    results = list(executor.map(geocode_address, addresses_to_query))

# 将查询结果存入缓存
location_cache = {address: (lat, lon) for address, lat, lon in results}

# %%
location_cache
# Out:
# {'Moody AFB': (30.97849, -83.21646)}

# %%
df.loc[df['latitude'].isna(), 'latitude'] = df.loc[df['latitude'].isna(), 'sampling_location'].map(
    lambda x: location_cache.get(x, (None, None))[0]
)

df.loc[df['longitude'].isna(), 'longitude'] = df.loc[df['longitude'].isna(), 'sampling_location'].map(
    lambda x: location_cache.get(x, (None, None))[1]
)

# %%
df
# Out:
#      sample_id sampling_location data_source  latitude  longitude  \
# 0    FA93251-1         Moody AFB         DoD  30.97849  -83.21646
# 1    FA93251-1         Moody AFB         DoD  30.97849  -83.21646
# 2    FA93251-1         Moody AFB         DoD  30.97849  -83.21646
# 3    FA93251-1         Moody AFB         DoD  30.97849  -83.21646
# 4    FA93251-1         Moody AFB         DoD  30.97849  -83.21646
# ..         ...               ...         ...       ...        ...
# 139  FA93250-3         Moody AFB         DoD  30.97849  -83.21646
# 140  FA93250-3         Moody AFB         DoD  30.97849  -83.21646
# 141  FA93250-3         Moody AFB         DoD  30.97849  -83.21646
# 142  FA93250-3         Moody AFB         DoD  30.97849  -83.21646
# 143  FA93250-3         Moody AFB         DoD  30.97849  -83.21646
#
#     sampling_date pws_id water_system_name  population well_type  ...  city  \
# 0      2022-02-15    NaN               NaN         NaN       NaN  ...   NaN
# 1      2022-02-15    NaN               NaN         NaN       NaN  ...   NaN
# 2      2022-02-15    NaN               NaN         NaN       NaN  ...   NaN
# 3      2022-02-15    NaN               NaN         NaN       NaN  ...   NaN
# 4      2022-02-15    NaN               NaN         NaN       NaN  ...   NaN
# ..            ...    ...               ...         ...       ...  ...   ...
# 139    2022-02-15    NaN               NaN         NaN       NaN  ...   NaN
# 140    2022-02-15    NaN               NaN         NaN       NaN  ...   NaN
# 141    2022-02-15    NaN               NaN         NaN       NaN  ...   NaN
# 142    2022-02-15    NaN               NaN         NaN       NaN  ...   NaN
# 143    2022-02-15    NaN               NaN         NaN       NaN  ...   NaN
#
#     county MRL DL analytical_methods is_detected   analyte  concentration  \
# 0      NaN NaN  8            QSM_B15       False    4:2FTS            0.0
# 1      NaN NaN  8            QSM_B15       False    6:2FTS            0.0
# 2      NaN NaN  8            QSM_B15       False    8:2FTS            0.0
# 3      NaN NaN  8            QSM_B15       False  NETFOSAA            0.0
# 4      NaN NaN  8            QSM_B15       False  NMEFOSAA            0.0
# ..     ...  .. ..                ...         ...       ...            ...
# 139    NaN NaN  4            QSM_B15        True     PFPES            3.6
# 140    NaN NaN  4            QSM_B15        True     PFPEA           12.9
# 141    NaN NaN  4            QSM_B15       False    PFTEDA            0.0
# 142    NaN NaN  4            QSM_B15       False    PFTRDA            0.0
# 143    NaN NaN  4            QSM_B15       False     PFUNA            0.0
#
#     pfas_total  note
# 0          NaN   NaN
# 1          NaN   NaN
# 2          NaN   NaN
# 3          NaN   NaN
# 4          NaN   NaN
# ..         ...   ...
# 139        NaN   NaN
# 140        NaN   NaN
# 141        NaN   NaN
# 142        NaN   NaN
# 143        NaN   NaN
#
# [144 rows x 24 columns]

# %%
df.to_csv('georgia_dw.csv')
