# %%
import pandas as pd
import camelot
import os
import numpy as np

# %%
os.getcwd()
# Out:
# '/Users/chuqiwang/Desktop/US_PFAS_Project/Kansas'

# %%
ks_df1 = pd.read_excel('Export_McConnell AFB.xlsx')

# %%
ks_df1
# Out:
#      Component ID  Component   State Installation Name Installation Type  \
# 0            5700  Air Force  Kansas     McConnell AFB            Active
# 1            5700  Air Force  Kansas     McConnell AFB            Active
# 2            5700  Air Force  Kansas     McConnell AFB            Active
# 3            5700  Air Force  Kansas     McConnell AFB            Active
# 4            5700  Air Force  Kansas     McConnell AFB            Active
# ..            ...        ...     ...               ...               ...
# 379          5700  Air Force  Kansas     McConnell AFB            Active
# 380          5700  Air Force  Kansas     McConnell AFB            Active
# 381          5700  Air Force  Kansas     McConnell AFB            Active
# 382          5700  Air Force  Kansas     McConnell AFB            Active
# 383          5700  Air Force  Kansas     McConnell AFB            Active
#
#     Lab Report Id Laboratory Sample ID Sample Date Analysis Method  \
# ...

# %%
columns = {
    'sample_id': str,
    'sampling_location': str,
    'data_source': str,
    'latitude': float,
    'longitude': float,
    'sampling_date': 'datetime64[ns]',
    'pws_id': str,
    'water_system_name': str,
    'population': int,
    'well_type': str,
    'well_depth': float,
    'units': str,
    'source_type': str,
    'state': str,
    'city': str,
    'county': str,
    'MRL': float,
    'DL': float,
    'analytical_methods': str,
    'is_detected': bool,
    'analyte': str,
    'concentration': float,
    'pfas_total': float,
    'note': str   
}

# %%
df1 = pd.DataFrame({col: pd.Series(dtype=dt) for col, dt in columns.items()})

# %%
df1['analyte'] = ks_df1['Analyte Abbreviation'].str.upper()
df1['concentration'] = ks_df1['Final Result'].fillna(0)
df1['sampling_location'] = ks_df1['Installation Name']
df1['DL'] = ks_df1['Limit of Detection']
df1['sampling_date'] = pd.to_datetime(ks_df1['Sample Date'])
df1['sample_id'] = ks_df1['Laboratory Sample ID']
df1['units'] = ks_df1['Final Units']
df1['state'] = ks_df1['State']
df1['analytical_methods'] = ks_df1['Analysis Method']
df1['data_source'] = 'DoD'
df1['source_type'] = 'drinking water'

# %%
df1['is_detected'] = df1['concentration'] != 0

# %%
df1
# Out:
#      sample_id sampling_location data_source  latitude  longitude  \
# 0    FA93617-1     McConnell AFB         DoD       NaN        NaN
# 1    FA93617-1     McConnell AFB         DoD       NaN        NaN
# 2    FA93617-1     McConnell AFB         DoD       NaN        NaN
# 3    FA93617-1     McConnell AFB         DoD       NaN        NaN
# 4    FA93617-1     McConnell AFB         DoD       NaN        NaN
# ..         ...               ...         ...       ...        ...
# 379  FC12947-2     McConnell AFB         DoD       NaN        NaN
# 380  FC12947-2     McConnell AFB         DoD       NaN        NaN
# 381  FC12947-2     McConnell AFB         DoD       NaN        NaN
# 382  FC12947-2     McConnell AFB         DoD       NaN        NaN
# 383  FC12947-2     McConnell AFB         DoD       NaN        NaN
#
#     sampling_date pws_id water_system_name  population well_type  ...  city  \
# 0      2022-03-02    NaN               NaN         NaN       NaN  ...   NaN
# ...

# %%
df1.to_csv('kansas_dw.csv')
