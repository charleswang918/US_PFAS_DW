# %%
import pandas as pd
import os
import numpy as np

# %%
os.getcwd()
# Out:
# '/Users/chuqiwang/Desktop/US_PFAS_Project/NorthCarolina'

# %%
nc_df1 = pd.read_excel('Export_CAMP LEJEUNE NC MCB.xlsx')

# %%
nc_df1
# Out:
#     Component ID Component           State    Installation Name  \
# 0           1700      Navy  North Carolina  CAMP LEJEUNE NC MCB
# 1           1700      Navy  North Carolina  CAMP LEJEUNE NC MCB
# 2           1700      Navy  North Carolina  CAMP LEJEUNE NC MCB
# 3           1700      Navy  North Carolina  CAMP LEJEUNE NC MCB
# 4           1700      Navy  North Carolina  CAMP LEJEUNE NC MCB
# 5           1700      Navy  North Carolina  CAMP LEJEUNE NC MCB
# 6           1700      Navy  North Carolina  CAMP LEJEUNE NC MCB
# 7           1700      Navy  North Carolina  CAMP LEJEUNE NC MCB
# 8           1700      Navy  North Carolina  CAMP LEJEUNE NC MCB
# 9           1700      Navy  North Carolina  CAMP LEJEUNE NC MCB
# 10          1700      Navy  North Carolina  CAMP LEJEUNE NC MCB
# 11          1700      Navy  North Carolina  CAMP LEJEUNE NC MCB
# 12          1700      Navy  North Carolina  CAMP LEJEUNE NC MCB
# 13          1700      Navy  North Carolina  CAMP LEJEUNE NC MCB
# ...

# %%
columns = {
    'sample_id': str,
    'sampling_location': str,
    'data_source': str,
    'latitude': float,
    'longitude': float,
    'sampling_date': 'datetime64[ns]',
    'pws_id': str,
    'water_system_name': str,
    'population': int,
    'well_type': str,
    'well_depth': float,
    'units': str,
    'source_type': str,
    'state': str,
    'city': str,
    'county': str,
    'MRL': float,
    'DL': float,
    'analytical_methods': str,
    'is_detected': bool,
    'analyte': str,
    'concentration': float,
    'pfas_total': float,
    'note': str   
}

# %%
df1 = pd.DataFrame({col: pd.Series(dtype=dt) for col, dt in columns.items()})
df1['analyte'] = nc_df1['Analyte Abbreviation'].str.upper()
df1['concentration'] = nc_df1['Final Result'].fillna(0)
df1['sampling_location'] = nc_df1['Installation Name']
df1['DL'] =nc_df1['Limit of Detection']
df1['sampling_date'] = pd.to_datetime(nc_df1['Sample Date'])
df1['sample_id'] = nc_df1['Laboratory Sample ID']
df1['units'] = nc_df1['Final Units']
df1['state'] = nc_df1['State']
df1['analytical_methods'] = nc_df1['Analysis Method']
df1['data_source'] = 'DoD'
df1['source_type'] = 'drinking water'

# %%
df1['is_detected'] = df1['concentration'] != 0

# %%
df1
# Out:
#    sample_id    sampling_location data_source  latitude  longitude  \
# 0   F2698-FS  CAMP LEJEUNE NC MCB         DoD       NaN        NaN
# 1   F2698-FS  CAMP LEJEUNE NC MCB         DoD       NaN        NaN
# 2   F2698-FS  CAMP LEJEUNE NC MCB         DoD       NaN        NaN
# 3   F2698-FS  CAMP LEJEUNE NC MCB         DoD       NaN        NaN
# 4   F2698-FS  CAMP LEJEUNE NC MCB         DoD       NaN        NaN
# 5   F2698-FS  CAMP LEJEUNE NC MCB         DoD       NaN        NaN
# 6   F2698-FS  CAMP LEJEUNE NC MCB         DoD       NaN        NaN
# 7   F2698-FS  CAMP LEJEUNE NC MCB         DoD       NaN        NaN
# 8   F2698-FS  CAMP LEJEUNE NC MCB         DoD       NaN        NaN
# 9   F2698-FS  CAMP LEJEUNE NC MCB         DoD       NaN        NaN
# 10  F2698-FS  CAMP LEJEUNE NC MCB         DoD       NaN        NaN
# 11  F2698-FS  CAMP LEJEUNE NC MCB         DoD       NaN        NaN
# 12  F2698-FS  CAMP LEJEUNE NC MCB         DoD       NaN        NaN
# ...

# %%
nc_df2 = pd.read_excel('Export_CHERRY POINT NC MCAS.xlsx')

# %%
df2 = pd.DataFrame({col: pd.Series(dtype=dt) for col, dt in columns.items()})
df2['analyte'] = nc_df2['Analyte Abbreviation'].str.upper()
df2['concentration'] = nc_df2['Final Result'].fillna(0)
df2['sampling_location'] = nc_df2['Installation Name']
df2['DL'] =nc_df2['Limit of Detection']
df2['sampling_date'] = pd.to_datetime(nc_df2['Sample Date'])
df2['sample_id'] = nc_df2['Laboratory Sample ID']
df2['units'] = nc_df2['Final Units']
df2['state'] = nc_df2['State']
df2['analytical_methods'] = nc_df2['Analysis Method']
df2['data_source'] = 'DoD'
df2['source_type'] = 'drinking water'

# %%
df2['is_detected'] = df2['concentration'] != 0

# %%
nc_df3 = pd.read_excel('Export_Fort Bragg .xlsx')

# %%
df3 = pd.DataFrame({col: pd.Series(dtype=dt) for col, dt in columns.items()})
df3['analyte'] = nc_df3['Analyte Abbreviation'].str.upper()
df3['concentration'] = nc_df3['Final Result'].fillna(0)
df3['sampling_location'] = nc_df3['Installation Name']
df3['DL'] =nc_df3['Limit of Detection']
df3['sampling_date'] = pd.to_datetime(nc_df3['Sample Date'])
df3['sample_id'] = nc_df3['Laboratory Sample ID']
df3['units'] = nc_df3['Final Units']
df3['state'] = nc_df3['State']
df3['analytical_methods'] = nc_df3['Analysis Method']
df3['data_source'] = 'DoD'
df3['source_type'] = 'drinking water'

# %%
df3['is_detected'] = df3['concentration'] != 0

# %%
nc_df4 = pd.read_excel('Export_Seymour Johnson AFB.xlsx')

# %%
df4 = pd.DataFrame({col: pd.Series(dtype=dt) for col, dt in columns.items()})
df4['analyte'] = nc_df4['Analyte Abbreviation'].str.upper()
df4['concentration'] = nc_df4['Final Result'].fillna(0)
df4['sampling_location'] = nc_df4['Installation Name']
df4['DL'] =nc_df4['Limit of Detection']
df4['sampling_date'] = pd.to_datetime(nc_df4['Sample Date'])
df4['sample_id'] = nc_df4['Laboratory Sample ID']
df4['units'] = nc_df4['Final Units']
df4['state'] = nc_df4['State']
df4['analytical_methods'] = nc_df4['Analysis Method']
df4['data_source'] = 'DoD'
df4['source_type'] = 'drinking water'

# %%
df4['is_detected'] = df4['concentration'] != 0

# %%
df = pd.concat([df1, df2, df3, df4])

# %%
df.index = range(0, len(df))

# %%
df
# Out:
#       sample_id    sampling_location data_source  latitude  longitude  \
# 0      F2698-FS  CAMP LEJEUNE NC MCB         DoD       NaN        NaN
# 1      F2698-FS  CAMP LEJEUNE NC MCB         DoD       NaN        NaN
# 2      F2698-FS  CAMP LEJEUNE NC MCB         DoD       NaN        NaN
# 3      F2698-FS  CAMP LEJEUNE NC MCB         DoD       NaN        NaN
# 4      F2698-FS  CAMP LEJEUNE NC MCB         DoD       NaN        NaN
# ...         ...                  ...         ...       ...        ...
# 3680  FC12281-3  Seymour Johnson AFB         DoD       NaN        NaN
# 3681  FC12281-3  Seymour Johnson AFB         DoD       NaN        NaN
# 3682  FC12281-3  Seymour Johnson AFB         DoD       NaN        NaN
# 3683  FC12281-3  Seymour Johnson AFB         DoD       NaN        NaN
# 3684  FC12281-3  Seymour Johnson AFB         DoD       NaN        NaN
#
#      sampling_date pws_id water_system_name  population well_type  ...  city  \
# ...

# %%
df.to_csv('northcarolina_dw.csv')
