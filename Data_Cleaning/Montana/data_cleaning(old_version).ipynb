# %%
import pandas as pd
import camelot
import os
import numpy as np

# %%
os.getcwd()
# Out:
# '/Users/chuqiwang/Desktop/US_PFAS_Project/Montana'

# %%
tables = camelot.read_pdf("DENIX,04.26.2019-NGB-PFAS-DW.pdf", pages='all', flavor='stream')

# %%
len(tables)
# Out:
# 59

# %%
tables
# Out:
# <TableList n=59>

# %%
a1 = tables[0].df

# %%
a1.iloc[1][8] = 'Result'
# Out:
# /var/folders/m8/kh2nk5652k94h_n7lqjvr8n00000gn/T/ipykernel_60356/709224632.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   a1.iloc[1][8] = 'Result'

# %%
a1 = a1.drop(columns=7)

# %%
a1 = a1.drop([0,1])

# %%
cols = [
    'Location Name', 'State', 'Water System Name', 'PWS ID', 'Component Name', 'Sample Date Time',
    'Analyte Name', 'Result', 'Reporting Limit', 'Unit', 'Clp Flags', 'Method Name'
]

# %%
a1.columns = cols

# %%
a1.index = range(1, len(a1) + 1)

# %%
a1 = a1.drop(columns='PWS ID')

# %%
a1
# Out:
#                           Location Name State  \
# 1                    US, NY, Camp Smith    NY
# 2                    US, NY, Camp Smith    NY
# 3                    US, NY, Camp Smith    NY
# 4                    US, NY, Camp Smith    NY
# 5                    US, NY, Camp Smith    NY
# ..                                  ...   ...
# 104  US, CA, Joint Forces Training Base    CA
# 105  US, CA, Joint Forces Training Base    CA
# 106  US, CA, Joint Forces Training Base    CA
# 107  US, CA, Joint Forces Training Base    CA
# 108  US, CA, Joint Forces Training Base    CA
#
#                           Water System Name             Component Name  \
# 1                                Camp Sm th             Camp Sm th-PDS
# 2                                Camp Sm th             Camp Sm th-PDS
# 3                                Camp Sm th             Camp Sm th-PDS
# 4                                Camp Sm th             Camp Sm th-PDS
# ...

# %%
a2 = tables[2].df
cols.remove('PWS ID')
a2.columns = cols

# %%
final_table = pd.concat([a1,a2])

# %%
final_table
# Out:
#                     Location Name State Water System Name      Component Name  \
# 1              US, NY, Camp Smith    NY        Camp Sm th      Camp Sm th-PDS
# 2              US, NY, Camp Smith    NY        Camp Sm th      Camp Sm th-PDS
# 3              US, NY, Camp Smith    NY        Camp Sm th      Camp Sm th-PDS
# 4              US, NY, Camp Smith    NY        Camp Sm th      Camp Sm th-PDS
# 5              US, NY, Camp Smith    NY        Camp Sm th      Camp Sm th-PDS
# ..                            ...   ...               ...                 ...
# 106  US, CA, Camp Roberts (067 7)    CA      Camp Roberts  Camp Roberts-17WWP
# 107  US, CA, Camp Roberts (067 7)    CA      Camp Roberts  Camp Roberts-17WWP
# 108  US, CA, Camp Roberts (067 7)    CA      Camp Roberts  Camp Roberts-17WWP
# 109  US, CA, Camp Roberts (067 7)    CA      Camp Roberts  Camp Roberts-17WWP
# 110  US, CA, Camp Roberts (067 7)    CA      Camp Roberts  Camp Roberts-17WWP
#
# ...

# %%
for i in range(4,59):
    print(i, tables[i].shape)
# Out:
# 4 (111, 11)
# 5 (111, 11)
# 6 (111, 11)
# 7 (111, 11)
# 8 (111, 11)
# 9 (111, 11)
# 10 (111, 11)
# 11 (111, 11)
# 12 (111, 11)
# 13 (111, 11)
# 14 (111, 11)
# 15 (111, 11)
# 16 (111, 11)
# 17 (111, 11)
# 18 (111, 11)
# 19 (111, 11)
# 20 (111, 11)
# 21 (111, 11)
# 22 (111, 11)
# 23 (111, 11)
# 24 (111, 11)
# 25 (111, 11)
# 26 (111, 11)
# 27 (111, 11)
# 28 (111, 11)
# 29 (111, 11)
# 30 (111, 11)
# 31 (111, 11)
# 32 (111, 14)
# 33 (111, 14)
# 34 (111, 11)
# 35 (111, 11)
# 36 (111, 11)
# 37 (111, 11)
# 38 (111, 11)
# 39 (111, 11)
# 40 (111, 11)
# 41 (111, 11)
# 42 (111, 11)
# 43 (111, 12)
# 44 (111, 11)
# 45 (111, 11)
# 46 (111, 11)
# 47 (111, 11)
# 48 (111, 11)
# 49 (111, 11)
# 50 (111, 11)
# 51 (111, 11)
# 52 (111, 11)
# 53 (111, 11)
# 54 (111, 12)
# 55 (111, 11)
# 56 (111, 11)
# 57 (111, 11)
# 58 (53, 10)

# %%
tables[33].df = tables[33].df.drop(columns=[1,4,5])

# %%
tables[33].df
# Out:
#                                   0   2                        3   \
# 0    US, NE, Greenl ef Training Si e  NE  Greenl ef Training S te
# 1    US, NE, Greenl ef Training Si e  NE  Greenl ef Training S te
# 2    US, NE, Greenl ef Training Si e  NE  Greenl ef Training S te
# 3    US, NE, Greenl ef Training Si e  NE  Greenl ef Training S te
# 4    US, NE, Greenl ef Training Si e  NE  Greenl ef Training S te
# ..                               ...  ..                      ...
# 106                  US, UT, Camp Wi  UT                  Camp Wi
# 107                  US, UT, Camp Wi  UT                  Camp Wi
# 108                  US, UT, Camp Wi  UT                  Camp Wi
# 109                  US, UT, Camp Wi  UT                  Camp Wi
# 110                  US, UT, Camp Wi  UT                  Camp Wi
#
#                                  6                    7   \
# 0    Greenl ef Training S te-W00312  0 /26/2017 12:00:00
# ...

# %%
tables[32].df[0]=tables[32].df[0]+tables[32].df[1]

# %%
tables[32].df = tables[32].df.drop(columns=1)

# %%
tables[32].df[3]=tables[32].df[3]+tables[32].df[4]

# %%
tables[32].df = tables[32].df.drop(columns=4)

# %%
tables[32].df[5]=tables[32].df[5]+tables[32].df[6]

# %%
tables[32].df = tables[32].df.drop(columns=6)

# %%
tables[32].df.shape
# Out:
# (111, 11)

# %%
for i in range(4,59):
    print(i, tables[i].df.shape)
# Out:
# 4 (111, 11)
# 5 (111, 11)
# 6 (111, 11)
# 7 (111, 11)
# 8 (111, 11)
# 9 (111, 11)
# 10 (111, 11)
# 11 (111, 11)
# 12 (111, 11)
# 13 (111, 11)
# 14 (111, 11)
# 15 (111, 11)
# 16 (111, 11)
# 17 (111, 11)
# 18 (111, 11)
# 19 (111, 11)
# 20 (111, 11)
# 21 (111, 11)
# 22 (111, 11)
# 23 (111, 11)
# 24 (111, 11)
# 25 (111, 11)
# 26 (111, 11)
# 27 (111, 11)
# 28 (111, 11)
# 29 (111, 11)
# 30 (111, 11)
# 31 (111, 11)
# 32 (111, 11)
# 33 (111, 11)
# 34 (111, 11)
# 35 (111, 11)
# 36 (111, 11)
# 37 (111, 11)
# 38 (111, 11)
# 39 (111, 11)
# 40 (111, 11)
# 41 (111, 11)
# 42 (111, 11)
# 43 (111, 12)
# 44 (111, 11)
# 45 (111, 11)
# 46 (111, 11)
# 47 (111, 11)
# 48 (111, 11)
# 49 (111, 11)
# 50 (111, 11)
# 51 (111, 11)
# 52 (111, 11)
# 53 (111, 11)
# 54 (111, 12)
# 55 (111, 11)
# 56 (111, 11)
# 57 (111, 11)
# 58 (53, 10)

# %%
tables[43].df[3] = tables[43].df[3]+tables[43].df[4]

# %%
tables[43].df = tables[43].df.drop(columns=4)

# %%
tables[54].df[7] = tables[54].df[6] + tables[54].df[7]

# %%
tables[54].df = tables[54].df.drop(columns=6)

# %%
tables[54].df
# Out:
#                                      0   1   \
# 0                    US, NY, Camp Smith  NY
# 1                    US, NY, Camp Smith  NY
# 2                    US, NY, Camp Smith  NY
# 3                    US, NY, Camp Smith  NY
# 4                    US, NY, Camp Smith  NY
# ..                                  ...  ..
# 106  US, CA, Joint Forces Training Base  CA
# 107  US, CA, Joint Forces Training Base  CA
# 108  US, CA, Joint Forces Training Base  CA
# 109  US, CA, Joint Forces Training Base  CA
# 110  US, CA, Joint Forces Training Base  CA
#
#                                          2                            3   \
# 0                                Camp Sm th             Camp Sm th-Well2
# 1                                Camp Sm th             Camp Sm th-Well2
# 2                                Camp Sm th             Camp Sm th-Well2
# 3                                Camp Sm th             Camp Sm th-Well2
# ...

# %%
tables[58].df[10] = tables[58].df[9]

# %%
tables[58].df[9]=''

# %%
tables[58].df
# Out:
# (53, 11)

# %%
for i in range(4,59):
    print(i, tables[i].df.shape)
# Out:
# 4 (111, 11)
# 5 (111, 11)
# 6 (111, 11)
# 7 (111, 11)
# 8 (111, 11)
# 9 (111, 11)
# 10 (111, 11)
# 11 (111, 11)
# 12 (111, 11)
# 13 (111, 11)
# 14 (111, 11)
# 15 (111, 11)
# 16 (111, 11)
# 17 (111, 11)
# 18 (111, 11)
# 19 (111, 11)
# 20 (111, 11)
# 21 (111, 11)
# 22 (111, 11)
# 23 (111, 11)
# 24 (111, 11)
# 25 (111, 11)
# 26 (111, 11)
# 27 (111, 11)
# 28 (111, 11)
# 29 (111, 11)
# 30 (111, 11)
# 31 (111, 11)
# 32 (111, 11)
# 33 (111, 11)
# 34 (111, 11)
# 35 (111, 11)
# 36 (111, 11)
# 37 (111, 11)
# 38 (111, 11)
# 39 (111, 11)
# 40 (111, 11)
# 41 (111, 11)
# 42 (111, 11)
# 43 (111, 11)
# 44 (111, 11)
# 45 (111, 11)
# 46 (111, 11)
# 47 (111, 11)
# 48 (111, 11)
# 49 (111, 11)
# 50 (111, 11)
# 51 (111, 11)
# 52 (111, 11)
# 53 (111, 11)
# 54 (111, 11)
# 55 (111, 11)
# 56 (111, 11)
# 57 (111, 11)
# 58 (53, 11)

# %%
for i in range(4,59):
    a=tables[i].df
    a.columns = cols
    final_table = pd.concat([final_table,a])

# %%
final_table['PWS ID']=''

# %%
final_table
# Out:
#                              Location Name State  \
# 1                       US, NY, Camp Smith    NY
# 2                       US, NY, Camp Smith    NY
# 3                       US, NY, Camp Smith    NY
# 4                       US, NY, Camp Smith    NY
# 5                       US, NY, Camp Smith    NY
# ..                                     ...   ...
# 48  US, NH, Cen er Strafford Training Si e    NH
# 49  US, NH, Cen er Strafford Training Si e    NH
# 50  US, NH, Cen er Strafford Training Si e    NH
# 51  US, NH, Cen er Strafford Training Si e    NH
# 52  US, NH, Cen er Strafford Training Si e    NH
#
#                              Water System Name  \
# 1                                   Camp Sm th
# 2                                   Camp Sm th
# 3                                   Camp Sm th
# 4                                   Camp Sm th
# 5                                   Camp Sm th
# ..                                         ...
# ...

# %%
final_table.to_csv('output.csv', index=False)

# %%
mt_df = final_table[final_table['State'] == 'MT']

# %%
mt_df
# Out:
#                             Location Name State  \
# 63              US, MT, Bi\nlings NG Site    MT
# 64              US, MT, Bi\nlings NG Site    MT
# 65              US, MT, Bi\nlings NG Site    MT
# 66              US, MT, Bi\nlings NG Site    MT
# 67              US, MT, Bi\nlings NG Site    MT
# 68              US, MT, Bi\nlings NG Site    MT
# 69              US, MT, Bi\nlings NG Site    MT
# 70              US, MT, Bi\nlings NG Site    MT
# 71              US, MT, Bi\nlings NG Site    MT
# 72              US, MT, Bi\nlings NG Site    MT
# 73              US, MT, Bi\nlings NG Site    MT
# 74              US, MT, Bi\nlings NG Site    MT
# 75              US, MT, Bi\nlings NG Site    MT
# 76              US, MT, Bi\nlings NG Site    MT
# 77              US, MT, Bi\nlings NG Site    MT
# 78              US, MT, Bi\nlings NG Site    MT
# 79              US, MT, Bi\nlings NG Site    MT
# 80              US, MT, Bi\nlings NG Site    MT
# ...

# %%
mt_df['Location Name']  = mt_df['Location Name'].replace({'US, MT, Bi\nlings NG Site': 'US, MT, Billings NG Site', 
                                                         'US, MT, Limestone Hil s Training Area': 'US, MT, Limestone Hills Training Area'})
# Out:
# /var/folders/m8/kh2nk5652k94h_n7lqjvr8n00000gn/T/ipykernel_60356/1350575060.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mt_df['Location Name']  = mt_df['Location Name'].replace({'US, MT, Bi\nlings NG Site': 'US, MT, Billings NG Site',

# %%
mt_df['Water System Name'] = mt_df['Water System Name'].replace({'B llings F eld Maintenance Shop 06': 'Billings Field Maintenance Shop 06', 
                                                                'Limestone Hi\nls Training Area': 'Limestone Hills Training Area'})
# Out:
# /var/folders/m8/kh2nk5652k94h_n7lqjvr8n00000gn/T/ipykernel_60356/3887790906.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mt_df['Water System Name'] = mt_df['Water System Name'].replace({'B llings F eld Maintenance Shop 06': 'Billings Field Maintenance Shop 06',

# %%
mt_df['analyte'] = mt_df['Analyte Name'].apply(lambda x: x.split()[-1]).str.replace(r'[()]', '', regex=True)
# Out:
# /var/folders/m8/kh2nk5652k94h_n7lqjvr8n00000gn/T/ipykernel_60356/1929647930.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mt_df['analyte'] = mt_df['Analyte Name'].apply(lambda x: x.split()[-1]).str.replace(r'[()]', '', regex=True)

# %%
mt_df['Component Name']  = mt_df['Component Name'].replace({'Bi\nlings FMS-Well1': 'Billings FMS-Well1', 'Bi\nlings FMS-PDS': 
                                                            'Billings FMS-PDS', 'Limes one Hi\nls Training Area-F': 'Limes one Hills Training Area-F'})
# Out:
# /var/folders/m8/kh2nk5652k94h_n7lqjvr8n00000gn/T/ipykernel_60356/4114073149.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mt_df['Component Name']  = mt_df['Component Name'].replace({'Bi\nlings FMS-Well1': 'Billings FMS-Well1', 'Bi\nlings FMS-PDS':

# %%
mt_df['Analyte Name']=mt_df['analyte'].str.upper()
# Out:
# /var/folders/m8/kh2nk5652k94h_n7lqjvr8n00000gn/T/ipykernel_60356/1783207560.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mt_df['Analyte Name']=mt_df['analyte'].str.upper()

# %%
mt_df = mt_df.drop(columns='analyte')

# %%
mt_df = mt_df.rename(columns={'Analyte Name': 'analyte'})

# %%
mt_df['Result'] = mt_df['Result'].replace('0.', '0')

# %%
mt_df['Result'] = mt_df['Result'].str.replace(' ', '')

# %%
mt_df['Reporting Limit'] = mt_df['Reporting Limit'].str.replace(' ','')

# %%
mt_df.dtypes
# Out:
# Location Name        object
# State                object
# Water System Name    object
# Component Name       object
# sampling_date        object
# analyte              object
# Result               object
# Reporting Limit      object
# Unit                 object
# Clp Flags            object
# Method Name          object
# PWS ID               object
# dtype: object

# %%
mt_df['Result'] = mt_df['Result'].astype(float)

# %%
mt_df['Reporting Limit'] = mt_df['Reporting Limit'].astype(float)

# %%
mt_df
# Out:
#                             Location Name State  \
# 63               US, MT, Billings NG Site    MT
# 64               US, MT, Billings NG Site    MT
# 65               US, MT, Billings NG Site    MT
# 66               US, MT, Billings NG Site    MT
# 67               US, MT, Billings NG Site    MT
# 68               US, MT, Billings NG Site    MT
# 69               US, MT, Billings NG Site    MT
# 70               US, MT, Billings NG Site    MT
# 71               US, MT, Billings NG Site    MT
# 72               US, MT, Billings NG Site    MT
# 73               US, MT, Billings NG Site    MT
# 74               US, MT, Billings NG Site    MT
# 75               US, MT, Billings NG Site    MT
# 76               US, MT, Billings NG Site    MT
# 77               US, MT, Billings NG Site    MT
# 78               US, MT, Billings NG Site    MT
# 79               US, MT, Billings NG Site    MT
# 80               US, MT, Billings NG Site    MT
# ...

# %%
mt_df['is_detected'] = mt_df['Result'] != 0

# %%
mt_df = mt_df.drop(columns='Clp Flags')

# %%
mt_df['Location Name'] = mt_df['Location Name'].str.replace('US, MT, ', '')

# %%
mt_df
# Out:
#                     Location Name State                   Water System Name  \
# 63               Billings NG Site    MT  Billings Field Maintenance Shop 06
# 64               Billings NG Site    MT  Billings Field Maintenance Shop 06
# 65               Billings NG Site    MT  Billings Field Maintenance Shop 06
# 66               Billings NG Site    MT  Billings Field Maintenance Shop 06
# 67               Billings NG Site    MT  Billings Field Maintenance Shop 06
# 68               Billings NG Site    MT  Billings Field Maintenance Shop 06
# 69               Billings NG Site    MT  Billings Field Maintenance Shop 06
# 70               Billings NG Site    MT  Billings Field Maintenance Shop 06
# 71               Billings NG Site    MT  Billings Field Maintenance Shop 06
# 72               Billings NG Site    MT  Billings Field Maintenance Shop 06
# 73               Billings NG Site    MT  Billings Field Maintenance Shop 06
# ...

# %%
mt_df = mt_df.rename(columns={'Sample Date Time': 'sampling_date'})

# %%
mt_df['sampling_date'] = mt_df['sampling_date'].replace('05/10/2017 08: 0:00', '05/10/2017 08:00:00')

# %%
mt_df['sampling_date'] = pd.to_datetime(mt_df['sampling_date'], format='%m/%d/%Y %H:%M:%S').dt.date

# %%
mt_df.dtypes
# Out:
# Location Name         object
# State                 object
# Water System Name     object
# Component Name        object
# sampling_date         object
# analyte               object
# Result               float64
# Reporting Limit      float64
# Unit                  object
# Method Name           object
# PWS ID                object
# is_detected             bool
# dtype: object

# %%
tmp_df = mt_df

# %%
tmp_df.to_csv('tmp_mt.csv')

# %%
tmp_df['sample_id'] = tmp_df['Component Name']

# %%
tmp_df['sample_id'] = tmp_df['sample_id'].replace({'Billings FMS-Well1': 'DW01', 'Billings FMS-PDS': 'DW02', 'Limes one Hills Training Area-F': 'DW03'})

# %%
tmp_df
# Out:
#                     Location Name State                   Water System Name  \
# 63               Billings NG Site    MT  Billings Field Maintenance Shop 06
# 64               Billings NG Site    MT  Billings Field Maintenance Shop 06
# 65               Billings NG Site    MT  Billings Field Maintenance Shop 06
# 66               Billings NG Site    MT  Billings Field Maintenance Shop 06
# 67               Billings NG Site    MT  Billings Field Maintenance Shop 06
# 68               Billings NG Site    MT  Billings Field Maintenance Shop 06
# 69               Billings NG Site    MT  Billings Field Maintenance Shop 06
# 70               Billings NG Site    MT  Billings Field Maintenance Shop 06
# 71               Billings NG Site    MT  Billings Field Maintenance Shop 06
# 72               Billings NG Site    MT  Billings Field Maintenance Shop 06
# 73               Billings NG Site    MT  Billings Field Maintenance Shop 06
# ...

# %%
columns = {
    'sample_id': str,
    'sampling_location': str,
    'data_source': str,
    'latitude': float,
    'longitude': float,
    'sampling_date': object,
    'pws_id': str,
    'population': int,
    'well_type': str,
    'well_depth': float,
    'units': str,
    'source_type': str,
    'state': str,
    'city': str,
    'county': str,
    'MRL': float,
    'DL': float,
    'analytical_methods': str,
    'is_detected': bool,
    'analyte': str,
    'concentration': float,
    'pfas_total': float,
    'note': str   
}

# %%
mt_df = pd.DataFrame({col: pd.Series(dtype=dt) for col, dt in columns.items()})

# %%
mt_df['is_detected'] = tmp_df['is_detected']
mt_df['analyte'] = tmp_df['analyte']
mt_df['concentration'] = tmp_df['Result']
mt_df['units'] = 'ng/L'
mt_df['sampling_date'] = tmp_df['sampling_date']
mt_df['state'] = tmp_df['State']
mt_df['city'] = 'Billings'
mt_df['county'] = 'Yellowstone'
mt_df['MRL'] = tmp_df['Reporting Limit']
mt_df['analytical_methods'] = tmp_df['Method Name']
mt_df['sampling_location'] = tmp_df['Location Name']
mt_df['data_source'] = 'PPL'
mt_df['sample_id'] = tmp_df['sample_id']

# %%
mt_df.index = range(0, len(mt_df))

# %%
mt_df.loc[mt_df['sampling_location'] == 'Limestone Hills Training Area', 'city'] = 'Townsend'
mt_df.loc[mt_df['sampling_location'] == 'Limestone Hills Training Area', 'county'] = 'Broadwater'

# %%
mt_df
# Out:
#    sample_id              sampling_location data_source  latitude  longitude  \
# 0       DW01               Billings NG Site         PPL       NaN        NaN
# 1       DW01               Billings NG Site         PPL       NaN        NaN
# 2       DW01               Billings NG Site         PPL       NaN        NaN
# 3       DW01               Billings NG Site         PPL       NaN        NaN
# 4       DW01               Billings NG Site         PPL       NaN        NaN
# 5       DW01               Billings NG Site         PPL       NaN        NaN
# 6       DW01               Billings NG Site         PPL       NaN        NaN
# 7       DW01               Billings NG Site         PPL       NaN        NaN
# 8       DW01               Billings NG Site         PPL       NaN        NaN
# 9       DW01               Billings NG Site         PPL       NaN        NaN
# 10      DW01               Billings NG Site         PPL       NaN        NaN
# ...

# %%
tables2 = camelot.read_pdf("345Rprt_FortWilliam_052722.pdf", pages='all')

# %%
analyte_list = tables2[0].df[0][5:33].str.upper()

# %%
analyte_df1 = analyte_list.to_frame(name='analyte')

# %%
analyte_df1 = pd.concat([analyte_df1] * 6, ignore_index=True)

# %%
sample_ids = []
num_samples = 6
analyte_length = len(analyte_list)

# %%
for i in range(num_samples):
    sample_ids.extend([f'DW{i+4}'] * analyte_length)

# %%
analyte_df1['sample_id'] = sample_ids
analyte_df1['sampling_date'] = pd.to_datetime('20211005').date()
analyte_df1['analytical_methods'] = 'B-15'

# %%
analyte_df1.loc[analyte_df1['sample_id'] == 'DW9', 'sampling_date'] = pd.to_datetime('20211028').date()

# %%
analyte_df1
# Out:
#      analyte sample_id sampling_date analytical_methods
# 0    4:2 FTS       DW4    2021-10-05               B-15
# 1    6:2 FTS       DW4    2021-10-05               B-15
# 2    8:2 FTS       DW4    2021-10-05               B-15
# 3      PFOSA       DW4    2021-10-05               B-15
# 4    NETFOSA       DW4    2021-10-05               B-15
# ..       ...       ...           ...                ...
# 163    PFPEA       DW9    2021-10-28               B-15
# 164    PFPES       DW9    2021-10-28               B-15
# 165   PFTEDA       DW9    2021-10-28               B-15
# 166   PFTRDA       DW9    2021-10-28               B-15
# 167   PFUNDA       DW9    2021-10-28               B-15
#
# [168 rows x 4 columns]

# %%
conc_list = []
dete_lim_list = []

for i in range (1, 7):
    data = list(tables2[0].df[i][5:33])
    for val in data:
        if '≤' in val:
            num = float(val.split(' ')[1])
            conc_list.append(0)
            dete_lim_list.append(num)
        else:
            num = float(val.split(' ')[0])
            conc_list.append(num)
            dete_lim_list.append('unknown')

# %%
analyte_df1['concentration'] = conc_list
analyte_df1['detection_limit'] = dete_lim_list

# %%
analyte_df1
# Out:
#      analyte sample_id sampling_date analytical_methods  concentration  \
# 0    4:2 FTS       DW4    2021-10-05               B-15            0.0
# 1    6:2 FTS       DW4    2021-10-05               B-15            0.0
# 2    8:2 FTS       DW4    2021-10-05               B-15            0.0
# 3      PFOSA       DW4    2021-10-05               B-15            0.0
# 4    NETFOSA       DW4    2021-10-05               B-15            0.0
# ..       ...       ...           ...                ...            ...
# 163    PFPEA       DW9    2021-10-28               B-15           25.1
# 164    PFPES       DW9    2021-10-28               B-15            6.2
# 165   PFTEDA       DW9    2021-10-28               B-15            0.0
# 166   PFTRDA       DW9    2021-10-28               B-15            0.0
# 167   PFUNDA       DW9    2021-10-28               B-15            0.0
#
#     detection_limit
# 0               3.1
# 1               3.1
# 2               3.1
# 3               2.0
# ...

# %%
analyte_df2 = analyte_list.to_frame(name='analyte')
analyte_df2 = pd.concat([analyte_df2] * 6, ignore_index=True)
sample_ids = []
num_samples = 6
analyte_length = len(analyte_list)
for i in range(num_samples):
    sample_ids.extend([f'DW{i+10}'] * analyte_length)

analyte_df2['sample_id'] = sample_ids
analyte_df2['sampling_date'] = pd.to_datetime('20211122').date()
analyte_df2['analytical_methods'] = 'B-15'

# %%
analyte_df2.loc[analyte_df2['sample_id'] == 'DW10', 'sampling_date'] = pd.to_datetime('20211028').date()

# %%
analyte_df2
# Out:
#      analyte sample_id sampling_date analytical_methods
# 0    4:2 FTS      DW10    2021-10-28               B-15
# 1    6:2 FTS      DW10    2021-10-28               B-15
# 2    8:2 FTS      DW10    2021-10-28               B-15
# 3      PFOSA      DW10    2021-10-28               B-15
# 4    NETFOSA      DW10    2021-10-28               B-15
# ..       ...       ...           ...                ...
# 163    PFPEA      DW15    2021-11-22               B-15
# 164    PFPES      DW15    2021-11-22               B-15
# 165   PFTEDA      DW15    2021-11-22               B-15
# 166   PFTRDA      DW15    2021-11-22               B-15
# 167   PFUNDA      DW15    2021-11-22               B-15
#
# [168 rows x 4 columns]

# %%
conc_list = []
dete_lim_list = []

for i in range (1, 7):
    data = list(tables2[1].df[i][5:33])
    for val in data:
        if '≤' in val:
            num = float(val.split(' ')[1])
            conc_list.append(0)
            dete_lim_list.append(num)
        else:
            num = float(val.split(' ')[0])
            conc_list.append(num)
            dete_lim_list.append('unknown')

analyte_df2['concentration'] = conc_list
analyte_df2['detection_limit'] = dete_lim_list

# %%
analyte_df2
# Out:
#      analyte sample_id sampling_date analytical_methods  concentration  \
# 0    4:2 FTS      DW10    2021-10-28               B-15            0.0
# 1    6:2 FTS      DW10    2021-10-28               B-15            0.0
# 2    8:2 FTS      DW10    2021-10-28               B-15            0.0
# 3      PFOSA      DW10    2021-10-28               B-15            0.0
# 4    NETFOSA      DW10    2021-10-28               B-15            0.0
# ..       ...       ...           ...                ...            ...
# 163    PFPEA      DW15    2021-11-22               B-15            4.3
# 164    PFPES      DW15    2021-11-22               B-15            1.9
# 165   PFTEDA      DW15    2021-11-22               B-15            0.0
# 166   PFTRDA      DW15    2021-11-22               B-15            0.0
# 167   PFUNDA      DW15    2021-11-22               B-15            0.0
#
#     detection_limit
# 0               3.0
# 1               3.0
# 2               3.0
# 3               2.0
# ...

# %%
tables2[2].df
# Out:
#                                                     0            1  \
# 0   Fort William Henry Harrison/JFHQ MT \nII \nRes...
# 1                              Laboratory \nSample ID  22111238908
# 2                            Sample Date \n(YYYYMMDD)     20211122
# 3                               Analysis Method  B-15
# 4                                               Units          ppt
# 5                                             4:2 FTS      ≤ 2.8 U
# 6                                             6:2 FTS      ≤ 2.8 U
# 7                                             8:2 FTS      ≤ 2.8 U
# 8                                               PFOSA          1 J
# 9                                             NEtFOSA      ≤ 3.7 U
# 10                                           NEtFOSAA      ≤ 3.7 U
# 11                                            NEtFOSE      ≤ 3.7 U
# 12                                            NMeFOSA      ≤ 3.7 U
# ...

# %%
analyte_df3 = analyte_list.to_frame(name='analyte')
analyte_df3 = pd.concat([analyte_df3] * 3, ignore_index=True)
sample_ids = []
num_samples = 3
analyte_length = len(analyte_list)
for i in range(num_samples):
    sample_ids.extend([f'DW{i+16}'] * analyte_length)

analyte_df3['sample_id'] = sample_ids
analyte_df3['sampling_date'] = pd.to_datetime('20211122').date()
analyte_df3['analytical_methods'] = 'B-15'

# %%
analyte_df3
# Out:
#     analyte sample_id sampling_date analytical_methods
# 0   4:2 FTS      DW16    2021-11-22               B-15
# 1   6:2 FTS      DW16    2021-11-22               B-15
# 2   8:2 FTS      DW16    2021-11-22               B-15
# 3     PFOSA      DW16    2021-11-22               B-15
# 4   NETFOSA      DW16    2021-11-22               B-15
# ..      ...       ...           ...                ...
# 79    PFPEA      DW18    2021-11-22               B-15
# 80    PFPES      DW18    2021-11-22               B-15
# 81   PFTEDA      DW18    2021-11-22               B-15
# 82   PFTRDA      DW18    2021-11-22               B-15
# 83   PFUNDA      DW18    2021-11-22               B-15
#
# [84 rows x 4 columns]

# %%
conc_list = []
dete_lim_list = []

for i in range (1, 4):
    data = list(tables2[2].df[i][5:33])
    for val in data:
        if '≤' in val:
            num = float(val.split(' ')[1])
            conc_list.append(0)
            dete_lim_list.append(num)
        else:
            num = float(val.split(' ')[0])
            conc_list.append(num)
            dete_lim_list.append('unknown')

analyte_df3['concentration'] = conc_list
analyte_df3['detection_limit'] = dete_lim_list

# %%
analyte_df3
# Out:
#     analyte sample_id sampling_date analytical_methods  concentration  \
# 0   4:2 FTS      DW16    2021-11-22               B-15            0.0
# 1   6:2 FTS      DW16    2021-11-22               B-15            0.0
# 2   8:2 FTS      DW16    2021-11-22               B-15            0.0
# 3     PFOSA      DW16    2021-11-22               B-15            1.0
# 4   NETFOSA      DW16    2021-11-22               B-15            0.0
# ..      ...       ...           ...                ...            ...
# 79    PFPEA      DW18    2021-11-22               B-15           11.2
# 80    PFPES      DW18    2021-11-22               B-15            2.3
# 81   PFTEDA      DW18    2021-11-22               B-15            0.0
# 82   PFTRDA      DW18    2021-11-22               B-15            0.0
# 83   PFUNDA      DW18    2021-11-22               B-15            0.0
#
#    detection_limit
# 0              2.8
# 1              2.8
# 2              2.8
# 3          unknown
# 4              3.7
# ...

# %%
analyte_df = pd.concat([analyte_df1, analyte_df2, analyte_df3])

# %%
analyte_df.index = range(0, len(analyte_df))

# %%
analyte_df
# Out:
#      analyte sample_id sampling_date analytical_methods  concentration  \
# 0    4:2 FTS       DW4    2021-10-05               B-15            0.0
# 1    6:2 FTS       DW4    2021-10-05               B-15            0.0
# 2    8:2 FTS       DW4    2021-10-05               B-15            0.0
# 3      PFOSA       DW4    2021-10-05               B-15            0.0
# 4    NETFOSA       DW4    2021-10-05               B-15            0.0
# ..       ...       ...           ...                ...            ...
# 415    PFPEA      DW18    2021-11-22               B-15           11.2
# 416    PFPES      DW18    2021-11-22               B-15            2.3
# 417   PFTEDA      DW18    2021-11-22               B-15            0.0
# 418   PFTRDA      DW18    2021-11-22               B-15            0.0
# 419   PFUNDA      DW18    2021-11-22               B-15            0.0
#
#     detection_limit
# 0               3.1
# 1               3.1
# 2               3.1
# 3               2.0
# ...

# %%
set(analyte_df.loc[analyte_df['detection_limit'] == 'unknown']['analyte'])
# Out:
# {'6:2 FTS',
#  'PFBA',
#  'PFBS',
#  'PFHPA',
#  'PFHPS',
#  'PFHXA',
#  'PFHXS',
#  'PFOA',
#  'PFOS',
#  'PFOSA',
#  'PFPEA',
#  'PFPES'}

# %%
detection_limits = {
    '6:2 FTS': 2.8, 'PFBA': 3.3, 'PFBS': 1.9, 'PFHPA': 2.8, 'PFHPS': 2.8,
    'PFHXA': 1.9, 'PFHXS': 2.8, 'PFOA': 1.9, 'PFOS': 1.9, 'PFOSA': 1.9,
    'PFPEA': 1.9, 'PFPES': 2.8
}

# %%
analyte_df['detection_limit'] = analyte_df.apply(
    lambda row: detection_limits.get(row['analyte'], row['detection_limit']) if row['detection_limit'] == 'unknown' else row['detection_limit'],
    axis=1
)

# %%
analyte_df = analyte_df.rename(columns={'detection_limit': 'DL'})

# %%
analyte_df
# Out:
#      analyte sample_id sampling_date analytical_methods  concentration   DL
# 0    4:2 FTS       DW4    2021-10-05               B-15            0.0  3.1
# 1    6:2 FTS       DW4    2021-10-05               B-15            0.0  3.1
# 2    8:2 FTS       DW4    2021-10-05               B-15            0.0  3.1
# 3      PFOSA       DW4    2021-10-05               B-15            0.0  2.0
# 4    NETFOSA       DW4    2021-10-05               B-15            0.0  4.1
# ..       ...       ...           ...                ...            ...  ...
# 415    PFPEA      DW18    2021-11-22               B-15           11.2  1.9
# 416    PFPES      DW18    2021-11-22               B-15            2.3  2.8
# 417   PFTEDA      DW18    2021-11-22               B-15            0.0  3.1
# 418   PFTRDA      DW18    2021-11-22               B-15            0.0  3.1
# 419   PFUNDA      DW18    2021-11-22               B-15            0.0  3.1
#
# [420 rows x 6 columns]

# %%
mt_df2 = pd.DataFrame({col: pd.Series(dtype=dt) for col, dt in columns.items()})

# %%
mt_df2 = pd.concat([mt_df2, analyte_df])

# %%
mt_df2['sampling_location'] = 'Fort William Henry Harrison'
mt_df2['data_source'] = 'DoD'
mt_df2['units'] = 'ug/L'
mt_df2['source_type'] = 'drinking water'
mt_df2['state'] = 'MT'
mt_df2['city'] = 'Helena'
mt_df2['county'] = 'Lewis and Clark'

# %%
mt_df2.columns
# Out:
# Index(['sample_id', 'sampling_location', 'data_source', 'latitude',
#        'longitude', 'sampling_date', 'pws_id', 'population', 'well_type',
#        'well_depth', 'units', 'source_type', 'state', 'city', 'county', 'MRL',
#        'DL', 'analytical_methods', 'is_detected', 'analyte', 'concentration',
#        'pfas_total', 'note'],
#       dtype='object')

# %%
mt_df2['is_detected'] = mt_df2['concentration'] != 0

# %%
mt_df2
# Out:
#     sample_id            sampling_location data_source  latitude  longitude  \
# 0         DW4  Fort William Henry Harrison         DoD       NaN        NaN
# 1         DW4  Fort William Henry Harrison         DoD       NaN        NaN
# 2         DW4  Fort William Henry Harrison         DoD       NaN        NaN
# 3         DW4  Fort William Henry Harrison         DoD       NaN        NaN
# 4         DW4  Fort William Henry Harrison         DoD       NaN        NaN
# ..        ...                          ...         ...       ...        ...
# 415      DW18  Fort William Henry Harrison         DoD       NaN        NaN
# 416      DW18  Fort William Henry Harrison         DoD       NaN        NaN
# 417      DW18  Fort William Henry Harrison         DoD       NaN        NaN
# 418      DW18  Fort William Henry Harrison         DoD       NaN        NaN
# 419      DW18  Fort William Henry Harrison         DoD       NaN        NaN
#
# ...

# %%
mt_df['sample_id'] = mt_df['sample_id'].replace({'DW01':'DW1', 'DW02': 'DW2', 'DW03': 'DW3'})

# %%
df_MT = pd.concat([mt_df, mt_df2])

# %%
df_MT.index = range(0, len(df_MT))

# %%
df_MT.to_csv('df_MT.csv')

# %%
df_MT = pd.read_csv('df_MT.csv')

# %%
df_MT['state'] = 'Montana'

# %%
df_MT['state']
# Out:
# 0      Montana
# 1      Montana
# 2      Montana
# 3      Montana
# 4      Montana
#         ...
# 466    Montana
# 467    Montana
# 468    Montana
# 469    Montana
# 470    Montana
# Name: state, Length: 471, dtype: object

# %%
df_MT = df_MT.drop(columns='Unnamed: 0')

# %%
df_MT['sample_id'] = 'MT_' + df_MT['sample_id']

# %%
df_MT['source_type'] = 'drinking water'

# %%
df_MT['county'] = df_MT['county'].replace({'Yellowstone': 'Yellowstone County', 'Broadwater': 'Broadwater County', 'Lewis and Clark': 'Lewis and Clark County'})

# %%
df_MT.to_csv('df_MT.csv')
