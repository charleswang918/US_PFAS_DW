# %%
import pandas as pd
import os
import numpy as np

# %%
os.getcwd()
# Out:
# '/Users/chuqiwang/Desktop/US_PFAS_Project/Michigan'

# %%
mi_df1 = pd.read_excel('Export_Grand Ledge AASF.xlsx')

# %%
mi_df1
# Out:
#      Component ID Component     State Installation Name Installation Type  \
# 0            2100      Army  Michigan  Grand Ledge AASF    National Guard
# 1            2100      Army  Michigan  Grand Ledge AASF    National Guard
# 2            2100      Army  Michigan  Grand Ledge AASF    National Guard
# 3            2100      Army  Michigan  Grand Ledge AASF    National Guard
# 4            2100      Army  Michigan  Grand Ledge AASF    National Guard
# ..            ...       ...       ...               ...               ...
# 219          2100      Army  Michigan  Grand Ledge AASF    National Guard
# 220          2100      Army  Michigan  Grand Ledge AASF    National Guard
# 221          2100      Army  Michigan  Grand Ledge AASF    National Guard
# 222          2100      Army  Michigan  Grand Ledge AASF    National Guard
# 223          2100      Army  Michigan  Grand Ledge AASF    National Guard
#
#     Lab Report Id Laboratory Sample ID Sample Date Analysis Method  \
# ...

# %%
columns = {
    'sample_id': str,
    'sampling_location': str,
    'data_source': str,
    'latitude': float,
    'longitude': float,
    'sampling_date': 'datetime64[ns]',
    'pws_id': str,
    'water_system_name': str,
    'population': int,
    'well_type': str,
    'well_depth': float,
    'units': str,
    'source_type': str,
    'state': str,
    'city': str,
    'county': str,
    'MRL': float,
    'DL': float,
    'analytical_methods': str,
    'is_detected': bool,
    'analyte': str,
    'concentration': float,
    'pfas_total': float,
    'note': str   
}

# %%
df1 = pd.DataFrame({col: pd.Series(dtype=dt) for col, dt in columns.items()})
df1['analyte'] = mi_df1['Analyte Abbreviation'].str.upper()
df1['concentration'] = mi_df1['Final Result'].fillna(0)
df1['sampling_location'] = mi_df1['Installation Name']
df1['DL'] = mi_df1['Limit of Detection']
df1['sampling_date'] = pd.to_datetime(mi_df1['Sample Date'])
df1['sample_id'] = mi_df1['Laboratory Sample ID']
df1['units'] = mi_df1['Final Units']
df1['state'] = mi_df1['State']
df1['analytical_methods'] = mi_df1['Analysis Method']
df1['data_source'] = 'DoD'
df1['source_type'] = 'drinking water'

# %%
df1['is_detected'] = df1['concentration'] != 0

# %%
mi_df2 = pd.read_excel('Export_KI Sawyer AFB.xlsx')

# %%
df2 = pd.DataFrame({col: pd.Series(dtype=dt) for col, dt in columns.items()})
df2['analyte'] = mi_df2['Analyte Abbreviation'].str.upper()
df2['concentration'] = mi_df2['Final Result'].fillna(0)
df2['sampling_location'] = mi_df2['Installation Name']
df2['DL'] = mi_df2['Limit of Detection']
df2['sampling_date'] = pd.to_datetime(mi_df2['Sample Date'])
df2['sample_id'] = mi_df2['Laboratory Sample ID']
df2['units'] = mi_df2['Final Units']
df2['state'] = mi_df2['State']
df2['analytical_methods'] = mi_df2['Analysis Method']
df2['data_source'] = 'DoD'
df2['source_type'] = 'drinking water'

# %%
df2['is_detected'] = df2['concentration'] != 0

# %%
mi_df3 = pd.read_excel('Export_MTC-H Camp Grayling Airfield (installation-wide PAI).xlsx')

# %%
df3 = pd.DataFrame({col: pd.Series(dtype=dt) for col, dt in columns.items()})
df3['analyte'] = mi_df3['Analyte Abbreviation'].str.upper()
df3['concentration'] = mi_df3['Final Result'].fillna(0)
df3['sampling_location'] = mi_df3['Installation Name']
df3['DL'] = mi_df3['Limit of Detection']
df3['sampling_date'] = pd.to_datetime(mi_df3['Sample Date'])
df3['sample_id'] = mi_df3['Laboratory Sample ID']
df3['units'] = mi_df3['Final Units']
df3['state'] = mi_df3['State']
df3['analytical_methods'] = mi_df3['Analysis Method']
df3['data_source'] = 'DoD'
df3['source_type'] = 'drinking water'

# %%
df3['is_detected'] = df3['concentration'] != 0

# %%
mi_df4 = pd.read_excel('Export_Wurtsmith AFB.xlsx')

# %%
df4 = pd.DataFrame({col: pd.Series(dtype=dt) for col, dt in columns.items()})
df4['analyte'] = mi_df4['Analyte Abbreviation'].str.upper()
df4['concentration'] = mi_df4['Final Result'].fillna(0)
df4['sampling_location'] = mi_df4['Installation Name']
df4['DL'] = mi_df4['Limit of Detection']
df4['sampling_date'] = pd.to_datetime(mi_df4['Sample Date'])
df4['sample_id'] = mi_df4['Laboratory Sample ID']
df4['units'] = mi_df4['Final Units']
df4['state'] = mi_df4['State']
df4['analytical_methods'] = mi_df4['Analysis Method']
df4['data_source'] = 'DoD'
df4['source_type'] = 'drinking water'

# %%
df4['is_detected'] = df4['concentration'] != 0

# %%
df = pd.concat([df1, df2, df3, df4])

# %%
df.index = range(0, len(df))

# %%
df
# Out:
#          sample_id sampling_location data_source  latitude  longitude  \
# 0      YE19031-001  Grand Ledge AASF         DoD       NaN        NaN
# 1      YE19031-001  Grand Ledge AASF         DoD       NaN        NaN
# 2      YE19031-001  Grand Ledge AASF         DoD       NaN        NaN
# 3      YE19031-001  Grand Ledge AASF         DoD       NaN        NaN
# 4      YE19031-001  Grand Ledge AASF         DoD       NaN        NaN
# ...            ...               ...         ...       ...        ...
# 26024    FC12212-1     Wurtsmith AFB         DoD       NaN        NaN
# 26025    FC12212-1     Wurtsmith AFB         DoD       NaN        NaN
# 26026    FC12212-1     Wurtsmith AFB         DoD       NaN        NaN
# 26027    FC12212-1     Wurtsmith AFB         DoD       NaN        NaN
# 26028    FC12212-1     Wurtsmith AFB         DoD       NaN        NaN
#
#       sampling_date pws_id water_system_name  population well_type  ...  city  \
# ...

# %%
df.to_csv('michigan_dw.csv')
