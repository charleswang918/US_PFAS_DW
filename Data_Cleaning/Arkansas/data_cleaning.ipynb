# %%
import pandas as pd
import os
import numpy as np

# %%
os.getcwd()
# Out:
# '/Users/chuqiwang/Desktop/US_PFAS_Project/Arkansas'

# %%
ar_df1 = pd.read_excel('Export_Little Rock AFB.xlsx')

# %%
ar_df1
# Out:
#      Component ID  Component     State Installation Name Installation Type  \
# 0            5700  Air Force  Arkansas   Little Rock AFB            Active
# 1            5700  Air Force  Arkansas   Little Rock AFB            Active
# 2            5700  Air Force  Arkansas   Little Rock AFB            Active
# 3            5700  Air Force  Arkansas   Little Rock AFB            Active
# 4            5700  Air Force  Arkansas   Little Rock AFB            Active
# ..            ...        ...       ...               ...               ...
# 475          5700  Air Force  Arkansas   Little Rock AFB            Active
# 476          5700  Air Force  Arkansas   Little Rock AFB            Active
# 477          5700  Air Force  Arkansas   Little Rock AFB            Active
# 478          5700  Air Force  Arkansas   Little Rock AFB            Active
# 479          5700  Air Force  Arkansas   Little Rock AFB            Active
#
# ...

# %%
columns = {
    'sample_id': str,
    'sampling_location': str,
    'data_source': str,
    'latitude': float,
    'longitude': float,
    'sampling_date': 'datetime64[ns]',
    'pws_id': str,
    'water_system_name': str,
    'population': int,
    'well_type': str,
    'well_depth': float,
    'units': str,
    'source_type': str,
    'state': str,
    'city': str,
    'county': str,
    'MRL': float,
    'DL': float,
    'analytical_methods': str,
    'is_detected': bool,
    'analyte': str,
    'concentration': float,
    'pfas_total': float,
    'note': str   
}

# %%
df1 = pd.DataFrame({col: pd.Series(dtype=dt) for col, dt in columns.items()})
df1['analyte'] = ar_df1['Analyte Abbreviation'].str.upper()
df1['concentration'] = ar_df1['Final Result'].fillna(0)
df1['sampling_location'] = ar_df1['Installation Name']
df1['DL'] = ar_df1['Limit of Detection']
df1['sampling_date'] = pd.to_datetime(ar_df1['Sample Date'])
df1['sample_id'] = ar_df1['Laboratory Sample ID']
df1['units'] = ar_df1['Final Units']
df1['state'] = ar_df1['State']
df1['analytical_methods'] = ar_df1['Analysis Method']
df1['data_source'] = 'DoD'
df1['source_type'] = 'drinking water'

# %%
df1['is_detected'] = df1['concentration'] != 0

# %%
df1
# Out:
#      sample_id sampling_location data_source  latitude  longitude  \
# 0    FA96648-3   Little Rock AFB         DoD       NaN        NaN
# 1    FA96648-3   Little Rock AFB         DoD       NaN        NaN
# 2    FA96648-3   Little Rock AFB         DoD       NaN        NaN
# 3    FA96648-3   Little Rock AFB         DoD       NaN        NaN
# 4    FA96648-3   Little Rock AFB         DoD       NaN        NaN
# ..         ...               ...         ...       ...        ...
# 475   FC3669-8   Little Rock AFB         DoD       NaN        NaN
# 476   FC3669-8   Little Rock AFB         DoD       NaN        NaN
# 477   FC3669-8   Little Rock AFB         DoD       NaN        NaN
# 478   FC3669-8   Little Rock AFB         DoD       NaN        NaN
# 479   FC3669-8   Little Rock AFB         DoD       NaN        NaN
#
#     sampling_date pws_id water_system_name  population well_type  ...  city  \
# 0      2022-06-15    NaN               NaN         NaN       NaN  ...   NaN
# ...

# %%
df1.to_csv('arkansas_dw.csv')
