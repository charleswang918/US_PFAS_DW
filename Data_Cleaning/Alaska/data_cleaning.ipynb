# %%
import pandas as pd
import os
import numpy as np

# %%
os.getcwd()
# Out:
# '/Users/chuqiwang/Desktop/US_PFAS_Project/Alaska'

# %%
ak_df1 = pd.read_excel('Export_Joint Base Elmendorf-Richardson.xlsx')

# %%
ak_df1
# Out:
#     Component ID  Component   State                Installation Name  \
# 0           5700  Air Force  Alaska  Joint Base Elmendorf-Richardson
# 1           5700  Air Force  Alaska  Joint Base Elmendorf-Richardson
# 2           5700  Air Force  Alaska  Joint Base Elmendorf-Richardson
# 3           5700  Air Force  Alaska  Joint Base Elmendorf-Richardson
# 4           5700  Air Force  Alaska  Joint Base Elmendorf-Richardson
# 5           5700  Air Force  Alaska  Joint Base Elmendorf-Richardson
# 6           5700  Air Force  Alaska  Joint Base Elmendorf-Richardson
# 7           5700  Air Force  Alaska  Joint Base Elmendorf-Richardson
# 8           5700  Air Force  Alaska  Joint Base Elmendorf-Richardson
# 9           5700  Air Force  Alaska  Joint Base Elmendorf-Richardson
# 10          5700  Air Force  Alaska  Joint Base Elmendorf-Richardson
# 11          5700  Air Force  Alaska  Joint Base Elmendorf-Richardson
# 12          5700  Air Force  Alaska  Joint Base Elmendorf-Richardson
# ...

# %%
columns = {
    'sample_id': str,
    'sampling_location': str,
    'data_source': str,
    'latitude': float,
    'longitude': float,
    'sampling_date': 'datetime64[ns]',
    'pws_id': str,
    'water_system_name': str,
    'population': int,
    'well_type': str,
    'well_depth': float,
    'units': str,
    'source_type': str,
    'state': str,
    'city': str,
    'county': str,
    'MRL': float,
    'DL': float,
    'analytical_methods': str,
    'is_detected': bool,
    'analyte': str,
    'concentration': float,
    'pfas_total': float,
    'note': str   
}

# %%
df1 = pd.DataFrame({col: pd.Series(dtype=dt) for col, dt in columns.items()})
df1['analyte'] = ak_df1['Analyte Abbreviation'].str.upper()
df1['concentration'] = ak_df1['Final Result'].fillna(0)
df1['sampling_location'] = ak_df1['Installation Name']
df1['DL'] = ak_df1['Limit of Detection']
df1['sampling_date'] = pd.to_datetime(ak_df1['Sample Date'])
df1['sample_id'] = ak_df1['Laboratory Sample ID']
df1['units'] = ak_df1['Final Units']
df1['state'] = ak_df1['State']
df1['analytical_methods'] = ak_df1['Analysis Method']
df1['data_source'] = 'DoD'
df1['source_type'] = 'drinking water'

# %%
df1['is_detected'] = df1['concentration'] != 0

# %%
ak_df2 = pd.read_excel('Export_Galena Forward Operating Location.xlsx')

# %%
df2 = pd.DataFrame({col: pd.Series(dtype=dt) for col, dt in columns.items()})
df2['analyte'] = ak_df2['Analyte Abbreviation'].str.upper()
df2['concentration'] = ak_df2['Final Result'].fillna(0)
df2['sampling_location'] = ak_df2['Installation Name']
df2['DL'] = ak_df2['Limit of Detection']
df2['sampling_date'] = pd.to_datetime(ak_df2['Sample Date'])
df2['sample_id'] = ak_df2['Laboratory Sample ID']
df2['units'] = ak_df2['Final Units']
df2['state'] = ak_df2['State']
df2['analytical_methods'] = ak_df2['Analysis Method']
df2['data_source'] = 'DoD'
df2['source_type'] = 'drinking water'

# %%
df2['is_detected'] = df2['concentration'] != 0

# %%
ak_df3 = pd.read_excel('Export_Eielson AFB.xlsx')

# %%
df3 = pd.DataFrame({col: pd.Series(dtype=dt) for col, dt in columns.items()})
df3['analyte'] = ak_df3['Analyte Abbreviation'].str.upper()
df3['concentration'] = ak_df3['Final Result'].fillna(0)
df3['sampling_location'] = ak_df3['Installation Name']
df3['DL'] = ak_df3['Limit of Detection']
df3['sampling_date'] = pd.to_datetime(ak_df3['Sample Date'])
df3['sample_id'] = ak_df3['Laboratory Sample ID']
df3['units'] = ak_df3['Final Units']
df3['state'] = ak_df3['State']
df3['analytical_methods'] = ak_df3['Analysis Method']
df3['data_source'] = 'DoD'
df3['source_type'] = 'drinking water'

# %%
df3['is_detected'] = df3['concentration'] != 0

# %%
df = pd.concat([df1, df2, df3])

# %%
df.index = range(0, len(df))

# %%
df
# Out:
#         sample_id                sampling_location data_source  latitude  \
# 0     XJ04025-001  Joint Base Elmendorf-Richardson         DoD       NaN
# 1     XJ04025-001  Joint Base Elmendorf-Richardson         DoD       NaN
# 2     XJ04025-001  Joint Base Elmendorf-Richardson         DoD       NaN
# 3     XJ04025-001  Joint Base Elmendorf-Richardson         DoD       NaN
# 4     XJ04025-001  Joint Base Elmendorf-Richardson         DoD       NaN
# ..            ...                              ...         ...       ...
# 833  410-144688-2                      Eielson AFB         DoD       NaN
# 834  410-144688-2                      Eielson AFB         DoD       NaN
# 835  410-144688-2                      Eielson AFB         DoD       NaN
# 836  410-144688-2                      Eielson AFB         DoD       NaN
# 837  410-144688-2                      Eielson AFB         DoD       NaN
#
#      longitude sampling_date pws_id water_system_name  population well_type  \
# ...

# %%
df.to_csv('alaska_dw.csv')
