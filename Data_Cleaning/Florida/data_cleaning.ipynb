# %%
import pandas as pd
import os
import numpy as np

# %%
os.getcwd()
# Out:
# '/Users/chuqiwang/Documents/US_PFAS_Project/data_cleaning/Florida'

# %%
fl_df1 = pd.read_excel('Export_Avon Park Air Force Reserve.xlsx')

# %%
fl_df1
# Out:
#      Component ID  Component    State            Installation Name  \
# 0            5700  Air Force  Florida  Avon Park Air Force Reserve
# 1            5700  Air Force  Florida  Avon Park Air Force Reserve
# 2            5700  Air Force  Florida  Avon Park Air Force Reserve
# 3            5700  Air Force  Florida  Avon Park Air Force Reserve
# 4            5700  Air Force  Florida  Avon Park Air Force Reserve
# ..            ...        ...      ...                          ...
# 446          5700  Air Force  Florida  Avon Park Air Force Reserve
# 447          5700  Air Force  Florida  Avon Park Air Force Reserve
# 448          5700  Air Force  Florida  Avon Park Air Force Reserve
# 449          5700  Air Force  Florida  Avon Park Air Force Reserve
# 450          5700  Air Force  Florida  Avon Park Air Force Reserve
#
#     Installation Type Lab Report Id Laboratory Sample ID Sample Date  \
# 0              Active       FA91872            FA91872-2  12/19/2021
# ...

# %%
columns = {
    'sample_id': str,
    'sampling_location': str,
    'data_source': str,
    'latitude': float,
    'longitude': float,
    'sampling_date': 'datetime64[ns]',
    'pws_id': str,
    'water_system_name': str,
    'population': int,
    'well_type': str,
    'well_depth': float,
    'units': str,
    'source_type': str,
    'state': str,
    'city': str,
    'county': str,
    'MRL': float,
    'DL': float,
    'analytical_methods': str,
    'is_detected': bool,
    'analyte': str,
    'concentration': float,
    'pfas_total': float,
    'note': str   
}

# %%
df1 = pd.DataFrame({col: pd.Series(dtype=dt) for col, dt in columns.items()})
df1['analyte'] = fl_df1['Analyte Abbreviation'].str.upper()
df1['concentration'] = fl_df1['Final Result'].fillna(0)
df1['sampling_location'] = fl_df1['Installation Name']
df1['DL'] = fl_df1['Limit of Detection']
df1['sampling_date'] = pd.to_datetime(fl_df1['Sample Date'])
df1['sample_id'] = fl_df1['Laboratory Sample ID']
df1['units'] = fl_df1['Final Units']
df1['state'] = fl_df1['State']
df1['analytical_methods'] = fl_df1['Analysis Method']
df1['data_source'] = 'DoD'
df1['source_type'] = 'drinking water'

# %%
df1['is_detected'] = df1['concentration'] != 0

# %%
fl_df2 = pd.read_excel('Export_CID CORRY STATION.xlsx')

# %%
df2 = pd.DataFrame({col: pd.Series(dtype=dt) for col, dt in columns.items()})
df2['analyte'] = fl_df2['Analyte Abbreviation'].str.upper()
df2['concentration'] = fl_df2['Final Result'].fillna(0)
df2['sampling_location'] = fl_df2['Installation Name']
df2['DL'] = fl_df2['Limit of Detection']
df2['sampling_date'] = pd.to_datetime(fl_df2['Sample Date'])
df2['sample_id'] = fl_df2['Laboratory Sample ID']
df2['units'] = fl_df2['Final Units']
df2['state'] = fl_df2['State']
df2['analytical_methods'] = fl_df2['Analysis Method']
df2['data_source'] = 'DoD'
df2['source_type'] = 'drinking water'

# %%
df2['is_detected'] = df2['concentration'] != 0

# %%
fl_df3 = pd.read_excel('Export_Homestead Air Reserve Base.xlsx')

# %%
df3 = pd.DataFrame({col: pd.Series(dtype=dt) for col, dt in columns.items()})
df3['analyte'] = fl_df3['Analyte Abbreviation'].str.upper()
df3['concentration'] = fl_df3['Final Result'].fillna(0)
df3['sampling_location'] = fl_df3['Installation Name']
df3['DL'] = fl_df3['Limit of Detection']
df3['sampling_date'] = pd.to_datetime(fl_df3['Sample Date'])
df3['sample_id'] = fl_df3['Laboratory Sample ID']
df3['units'] = fl_df3['Final Units']
df3['state'] = fl_df3['State']
df3['analytical_methods'] = fl_df3['Analysis Method']
df3['data_source'] = 'DoD'
df3['source_type'] = 'drinking water'

# %%
df3['is_detected'] = df3['concentration'] != 0

# %%
fl_df4 = pd.read_excel('Export_Hurlburt Field.xlsx')

# %%
df4 = pd.DataFrame({col: pd.Series(dtype=dt) for col, dt in columns.items()})
df4['analyte'] = fl_df4['Analyte Abbreviation'].str.upper()
df4['concentration'] = fl_df4['Final Result'].fillna(0)
df4['sampling_location'] = fl_df4['Installation Name']
df4['DL'] = fl_df4['Limit of Detection']
df4['sampling_date'] = pd.to_datetime(fl_df4['Sample Date'])
df4['sample_id'] = fl_df4['Laboratory Sample ID']
df4['units'] = fl_df4['Final Units']
df4['state'] = fl_df4['State']
df4['analytical_methods'] = fl_df4['Analysis Method']
df4['data_source'] = 'DoD'
df4['source_type'] = 'drinking water'

# %%
df4['is_detected'] = df4['concentration'] != 0

# %%
fl_df5 = pd.read_excel('Export_SAUFLEY FLD FL NAS.xlsx')

# %%
df5 = pd.DataFrame({col: pd.Series(dtype=dt) for col, dt in columns.items()})
df5['analyte'] = fl_df5['Analyte Abbreviation'].str.upper()
df5['concentration'] = fl_df5['Final Result'].fillna(0)
df5['sampling_location'] = fl_df5['Installation Name']
df5['DL'] = fl_df5['Limit of Detection']
df5['sampling_date'] = pd.to_datetime(fl_df5['Sample Date'])
df5['sample_id'] = fl_df5['Laboratory Sample ID']
df5['units'] = fl_df5['Final Units']
df5['state'] = fl_df5['State']
df5['analytical_methods'] = fl_df5['Analysis Method']
df5['data_source'] = 'DoD'
df5['source_type'] = 'drinking water'

# %%
df5['is_detected'] = df5['concentration'] != 0

# %%
fl_df6 = pd.read_excel('Export_WHITING FLD FL NAS.xlsx')

# %%
df6 = pd.DataFrame({col: pd.Series(dtype=dt) for col, dt in columns.items()})
df6['analyte'] = fl_df6['Analyte Abbreviation'].str.upper()
df6['concentration'] = fl_df6['Final Result'].fillna(0)
df6['sampling_location'] = fl_df6['Installation Name']
df6['DL'] = fl_df6['Limit of Detection']
df6['sampling_date'] = pd.to_datetime(fl_df6['Sample Date'])
df6['sample_id'] = fl_df6['Laboratory Sample ID']
df6['units'] = fl_df6['Final Units']
df6['state'] = fl_df6['State']
df6['analytical_methods'] = fl_df6['Analysis Method']
df6['data_source'] = 'DoD'
df6['source_type'] = 'drinking water'

# %%
df6['is_detected'] = df6['concentration'] != 0

# %%
df = pd.concat([df1, df2, df3, df4, df5, df6])

# %%
df.index = range(0, len(df))

# %%
df
# Out:
#        sample_id            sampling_location data_source  latitude  \
# 0      FA91872-2  Avon Park Air Force Reserve         DoD       NaN
# 1      FA91872-2  Avon Park Air Force Reserve         DoD       NaN
# 2      FA91872-2  Avon Park Air Force Reserve         DoD       NaN
# 3      FA91872-2  Avon Park Air Force Reserve         DoD       NaN
# 4      FA91872-2  Avon Park Air Force Reserve         DoD       NaN
# ...          ...                          ...         ...       ...
# 6158  2401124-02           WHITING FLD FL NAS         DoD       NaN
# 6159  2401124-02           WHITING FLD FL NAS         DoD       NaN
# 6160  2401124-02           WHITING FLD FL NAS         DoD       NaN
# 6161  2401124-02           WHITING FLD FL NAS         DoD       NaN
# 6162  2401124-02           WHITING FLD FL NAS         DoD       NaN
#
#       longitude sampling_date pws_id water_system_name  population well_type  \
# ...

# %%
from concurrent.futures import ThreadPoolExecutor
import pandas as pd
from geopy.geocoders import OpenCage

geolocator = OpenCage(api_key="c7f16120befe4e3fb85e7a082e620fdb")

def geocode_address(address):
    try:
        location = geolocator.geocode(address)
        if location:
            return (address, location.latitude, location.longitude)
        else:
            return (address, None, None)
    except Exception as e:
        print(f"Error geocoding {address}: {e}")
        return (address, None, None)

# 假设 df 是您的数据框，以下是改进的代码
# 只提取需要查询的地址
addresses_to_query = df.loc[df['latitude'].isna() | df['longitude'].isna(), 'sampling_location'].unique()

# 用多线程处理查询任务
with ThreadPoolExecutor(max_workers=10) as executor:
    results = list(executor.map(geocode_address, addresses_to_query))

# 将查询结果存入缓存
location_cache = {address: (lat, lon) for address, lat, lon in results}

# %%
location_cache
# Out:
# {'Avon Park Air Force Reserve': (30.05381, -90.55175),
#  'CID CORRY STATION': (47.27103, 8.8218),
#  'Homestead Air Reserve Base': (25.4880184, -80.3948433),
#  'Hurlburt Field': (30.4312921, -86.6902291),
#  'SAUFLEY FLD FL NAS': (25.05823, -77.34306),
#  'WHITING FLD FL NAS': (25.05823, -77.34306)}

# %%
# 用缓存的数据批量更新缺失的纬度
df.loc[df['latitude'].isna(), 'latitude'] = df.loc[df['latitude'].isna(), 'sampling_location'].map(
    lambda x: location_cache.get(x, (None, None))[0]
)

# 用缓存的数据批量更新缺失的经度
df.loc[df['longitude'].isna(), 'longitude'] = df.loc[df['longitude'].isna(), 'sampling_location'].map(
    lambda x: location_cache.get(x, (None, None))[1]
)

# %%
df
# Out:
#        sample_id            sampling_location data_source  latitude  \
# 0      FA91872-2  Avon Park Air Force Reserve         DoD  30.05381
# 1      FA91872-2  Avon Park Air Force Reserve         DoD  30.05381
# 2      FA91872-2  Avon Park Air Force Reserve         DoD  30.05381
# 3      FA91872-2  Avon Park Air Force Reserve         DoD  30.05381
# 4      FA91872-2  Avon Park Air Force Reserve         DoD  30.05381
# ...          ...                          ...         ...       ...
# 6158  2401124-02           WHITING FLD FL NAS         DoD  25.05823
# 6159  2401124-02           WHITING FLD FL NAS         DoD  25.05823
# 6160  2401124-02           WHITING FLD FL NAS         DoD  25.05823
# 6161  2401124-02           WHITING FLD FL NAS         DoD  25.05823
# 6162  2401124-02           WHITING FLD FL NAS         DoD  25.05823
#
#       longitude sampling_date pws_id water_system_name  population well_type  \
# ...

# %%
df.to_csv('florida_dw.csv')
