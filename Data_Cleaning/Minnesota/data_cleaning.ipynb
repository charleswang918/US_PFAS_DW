# %%
import pandas as pd
import os
import numpy as np

# %%
os.getcwd()
# Out:
# '/Users/chuqiwang/Documents/US_PFAS_Project/data_cleaning/Minnesota'

# %%
mn_df1 = pd.read_excel('Export_Camp Ripley.xlsx')

# %%
mn_df1
# Out:
#       Component ID Component      State Installation Name Installation Type  \
# 0             2100      Army  Minnesota       Camp Ripley    National Guard
# 1             2100      Army  Minnesota       Camp Ripley    National Guard
# 2             2100      Army  Minnesota       Camp Ripley    National Guard
# 3             2100      Army  Minnesota       Camp Ripley    National Guard
# 4             2100      Army  Minnesota       Camp Ripley    National Guard
# ...            ...       ...        ...               ...               ...
# 1080          2100      Army  Minnesota       Camp Ripley    National Guard
# 1081          2100      Army  Minnesota       Camp Ripley    National Guard
# 1082          2100      Army  Minnesota       Camp Ripley    National Guard
# 1083          2100      Army  Minnesota       Camp Ripley    National Guard
# 1084          2100      Army  Minnesota       Camp Ripley    National Guard
#
#      Lab Report Id Laboratory Sample ID Sample Date Analysis Method  \
# 0          YE10039          YE10039-001    5/8/2023         QSM_B15
# 1          YE10039          YE10039-001    5/8/2023         QSM_B15
# 2          YE10039          YE10039-001    5/8/2023         QSM_B15
# 3          YE10039          YE10039-001    5/8/2023         QSM_B15
# 4          YE10039          YE10039-001    5/8/2023         QSM_B15
# ...            ...                  ...         ...             ...
# 1080  410-139133-1         410-139133-6   8/14/2023         QSM_B15
# 1081  410-139133-1         410-139133-6   8/14/2023         QSM_B15
# 1082  410-139133-1         410-139133-6   8/14/2023         QSM_B15
# 1083  410-139133-1         410-139133-6   8/14/2023         QSM_B15
# 1084  410-139133-1         410-139133-6   8/14/2023         QSM_B15
#
#       CAS Number Analyte Abbreviation  Final Result  Limit of Detection  \
# 0     13252-13-6              HFPO-DA           NaN                3.70
# 1      1763-23-1                 PFOS          49.0                1.90
# 2      2058-94-8                PFUnA           NaN                1.90
# 3      2355-31-9             NMeFOSAA           NaN                3.70
# 4      2706-90-3                PFPeA           3.8                1.90
# ...          ...                  ...           ...                 ...
# 1080   2706-91-4                PFPeS          27.0                0.82
# 1081   2706-90-3                PFPeA           9.8                0.82
# 1082    376-06-7               PFTeDA           NaN                0.82
# 1083  72629-94-8               PFTrDA           NaN                0.82
# 1084   2058-94-8                PFUnA           NaN                0.82
#
#      Final Units Final Qualification Treatment System Pre Or Post Treatment
# 0           ng/L                   U               No                   NaN
# 1           ng/L                 NaN               No                   NaN
# 2           ng/L                   U               No                   NaN
# 3           ng/L                   U               No                   NaN
# 4           ng/L                 NaN               No                   NaN
# ...          ...                 ...              ...                   ...
# 1080        ng/L                 NaN               No                   NaN
# 1081        ng/L                 NaN               No                   NaN
# 1082        ng/L                   U               No                   NaN
# 1083        ng/L                   U               No                   NaN
# 1084        ng/L                   U               No                   NaN
#
# [1085 rows x 17 columns]

# %%
columns = {
    'sample_id': str,
    'sampling_location': str,
    'data_source': str,
    'latitude': float,
    'longitude': float,
    'sampling_date': 'datetime64[ns]',
    'pws_id': str,
    'water_system_name': str,
    'population': int,
    'well_type': str,
    'well_depth': float,
    'units': str,
    'source_type': str,
    'state': str,
    'city': str,
    'county': str,
    'MRL': float,
    'DL': float,
    'analytical_methods': str,
    'is_detected': bool,
    'analyte': str,
    'concentration': float,
    'pfas_total': float,
    'note': str   
}

# %%
df1 = pd.DataFrame({col: pd.Series(dtype=dt) for col, dt in columns.items()})

# %%
df1['analyte'] = mn_df1['Analyte Abbreviation'].str.upper()
df1['concentration'] = mn_df1['Final Result'].fillna(0)
df1['sampling_location'] = mn_df1['Installation Name']
df1['DL'] = mn_df1['Limit of Detection']
df1['sampling_date'] = pd.to_datetime(mn_df1['Sample Date'])
df1['sample_id'] = mn_df1['Laboratory Sample ID']
df1['units'] = mn_df1['Final Units']
df1['state'] = mn_df1['State']
df1['analytical_methods'] = mn_df1['Analysis Method']
df1['data_source'] = 'DoD'
df1['source_type'] = 'drinking water'

# %%
df1['is_detected'] = df1['concentration'] != 0

# %%
df1
# Out:
#          sample_id sampling_location data_source  latitude  longitude  \
# 0      YE10039-001       Camp Ripley         DoD       NaN        NaN
# 1      YE10039-001       Camp Ripley         DoD       NaN        NaN
# 2      YE10039-001       Camp Ripley         DoD       NaN        NaN
# 3      YE10039-001       Camp Ripley         DoD       NaN        NaN
# 4      YE10039-001       Camp Ripley         DoD       NaN        NaN
# ...            ...               ...         ...       ...        ...
# 1080  410-139133-6       Camp Ripley         DoD       NaN        NaN
# 1081  410-139133-6       Camp Ripley         DoD       NaN        NaN
# 1082  410-139133-6       Camp Ripley         DoD       NaN        NaN
# 1083  410-139133-6       Camp Ripley         DoD       NaN        NaN
# 1084  410-139133-6       Camp Ripley         DoD       NaN        NaN
#
#      sampling_date pws_id water_system_name  population well_type  ...  city  \
# 0       2023-05-08    NaN               NaN         NaN       NaN  ...   NaN
# 1       2023-05-08    NaN               NaN         NaN       NaN  ...   NaN
# 2       2023-05-08    NaN               NaN         NaN       NaN  ...   NaN
# 3       2023-05-08    NaN               NaN         NaN       NaN  ...   NaN
# 4       2023-05-08    NaN               NaN         NaN       NaN  ...   NaN
# ...            ...    ...               ...         ...       ...  ...   ...
# 1080    2023-08-14    NaN               NaN         NaN       NaN  ...   NaN
# 1081    2023-08-14    NaN               NaN         NaN       NaN  ...   NaN
# 1082    2023-08-14    NaN               NaN         NaN       NaN  ...   NaN
# 1083    2023-08-14    NaN               NaN         NaN       NaN  ...   NaN
# 1084    2023-08-14    NaN               NaN         NaN       NaN  ...   NaN
#
#      county MRL    DL analytical_methods is_detected   analyte  concentration  \
# 0       NaN NaN  3.70            QSM_B15       False   HFPO-DA            0.0
# 1       NaN NaN  1.90            QSM_B15        True      PFOS           49.0
# 2       NaN NaN  1.90            QSM_B15       False     PFUNA            0.0
# 3       NaN NaN  3.70            QSM_B15       False  NMEFOSAA            0.0
# 4       NaN NaN  1.90            QSM_B15        True     PFPEA            3.8
# ...     ...  ..   ...                ...         ...       ...            ...
# 1080    NaN NaN  0.82            QSM_B15        True     PFPES           27.0
# 1081    NaN NaN  0.82            QSM_B15        True     PFPEA            9.8
# 1082    NaN NaN  0.82            QSM_B15       False    PFTEDA            0.0
# 1083    NaN NaN  0.82            QSM_B15       False    PFTRDA            0.0
# 1084    NaN NaN  0.82            QSM_B15       False     PFUNA            0.0
#
#      pfas_total  note
# 0           NaN   NaN
# 1           NaN   NaN
# 2           NaN   NaN
# 3           NaN   NaN
# 4           NaN   NaN
# ...         ...   ...
# 1080        NaN   NaN
# 1081        NaN   NaN
# 1082        NaN   NaN
# 1083        NaN   NaN
# 1084        NaN   NaN
#
# [1085 rows x 24 columns]

# %%
mn_df2 = pd.read_excel('Export_Camp Ripley (Installation Wide PA) (Western AOI SI).xlsx')

# %%
mn_df2
# Out:
#      Component ID Component      State  \
# 0            2100      Army  Minnesota
# 1            2100      Army  Minnesota
# 2            2100      Army  Minnesota
# 3            2100      Army  Minnesota
# 4            2100      Army  Minnesota
# ..            ...       ...        ...
# 547          2100      Army  Minnesota
# 548          2100      Army  Minnesota
# 549          2100      Army  Minnesota
# 550          2100      Army  Minnesota
# 551          2100      Army  Minnesota
#
#                                      Installation Name Installation Type  \
# 0    Camp Ripley (Installation Wide PA) (Western AO...    National Guard
# 1    Camp Ripley (Installation Wide PA) (Western AO...    National Guard
# 2    Camp Ripley (Installation Wide PA) (Western AO...    National Guard
# 3    Camp Ripley (Installation Wide PA) (Western AO...    National Guard
# 4    Camp Ripley (Installation Wide PA) (Western AO...    National Guard
# ..                                                 ...               ...
# 547  Camp Ripley (Installation Wide PA) (Western AO...    National Guard
# 548  Camp Ripley (Installation Wide PA) (Western AO...    National Guard
# 549  Camp Ripley (Installation Wide PA) (Western AO...    National Guard
# 550  Camp Ripley (Installation Wide PA) (Western AO...    National Guard
# 551  Camp Ripley (Installation Wide PA) (Western AO...    National Guard
#
#     Lab Report Id Laboratory Sample ID Sample Date Analysis Method  \
# 0    410-149644-1         410-149644-1  10/30/2023         QSM_B15
# 1    410-149644-1         410-149644-1  10/30/2023         QSM_B15
# 2    410-149644-1         410-149644-1  10/30/2023         QSM_B15
# 3    410-149644-1         410-149644-1  10/30/2023         QSM_B15
# 4    410-149644-1         410-149644-1  10/30/2023         QSM_B15
# ..            ...                  ...         ...             ...
# 547  410-161204-1         410-161204-4   2/18/2024           537.1
# 548  410-161204-1         410-161204-4   2/18/2024           537.1
# 549  410-161204-1         410-161204-4   2/18/2024           537.1
# 550  410-161204-1         410-161204-4   2/18/2024           537.1
# 551  410-161204-1         410-161204-4   2/18/2024           537.1
#
#       CAS Number Analyte Abbreviation  Final Result  Limit of Detection  \
# 0      1763-23-1                 PFOS          45.0                1.60
# 1      2058-94-8                PFUnA           NaN                0.81
# 2      2355-31-9             NMeFOSAA           NaN                0.97
# 3      2706-90-3                PFPeA           4.4                0.81
# 4      2706-91-4                PFPeS           4.9                0.81
# ..           ...                  ...           ...                 ...
# 547   39108-34-4               8:2FTS           NaN                1.80
# 548   68259-12-1                 PFNS           NaN                0.90
# 549   72629-94-8               PFTrDA           NaN                0.90
# 550     754-91-6                PFOSA           1.8                1.30
# 551  757124-72-4               4:2FTS           NaN                0.90
#
#     Final Units Final Qualification Treatment System Pre Or Post Treatment
# 0          ng/L                 NaN               No                   NaN
# 1          ng/L                   U               No                   NaN
# 2          ng/L                   U               No                   NaN
# 3          ng/L                 NaN               No                   NaN
# 4          ng/L                 NaN               No                   NaN
# ..          ...                 ...              ...                   ...
# 547        ng/L                   U              Yes         pre-treatment
# 548        ng/L                   U              Yes         pre-treatment
# 549        ng/L                   U              Yes         pre-treatment
# 550        ng/L                 NaN              Yes         pre-treatment
# 551        ng/L                   U              Yes         pre-treatment
#
# [552 rows x 17 columns]

# %%
df2 = pd.DataFrame({col: pd.Series(dtype=dt) for col, dt in columns.items()})
df2['analyte'] = mn_df2['Analyte Abbreviation'].str.upper()
df2['concentration'] = mn_df2['Final Result'].fillna(0)
df2['sampling_location'] = mn_df2['Installation Name']
df2['DL'] = mn_df2['Limit of Detection']
df2['sampling_date'] = pd.to_datetime(mn_df2['Sample Date'])
df2['sample_id'] = mn_df2['Laboratory Sample ID']
df2['units'] = mn_df2['Final Units']
df2['state'] = mn_df2['State']
df2['analytical_methods'] = mn_df2['Analysis Method']
df2['data_source'] = 'DoD'
df2['source_type'] = 'drinking water'

# %%
df = pd.concat([df1, df2])

# %%
from concurrent.futures import ThreadPoolExecutor
import pandas as pd
from geopy.geocoders import OpenCage

geolocator = OpenCage(api_key="1f1adf3211e64148bfe6de5e054906f8")

def geocode_address(address):
    try:
        location = geolocator.geocode(address)
        if location:
            return (address, location.latitude, location.longitude)
        else:
            return (address, None, None)
    except Exception as e:
        print(f"Error geocoding {address}: {e}")
        return (address, None, None)

addresses_to_query = df.loc[df['latitude'].isna() | df['longitude'].isna(), 'sampling_location'].unique()

with ThreadPoolExecutor(max_workers=10) as executor:
    results = list(executor.map(geocode_address, addresses_to_query))

location_cache = {address: (lat, lon) for address, lat, lon in results}

# %%
location_cache
# Out:
# {'Camp Ripley': (46.2026955, -94.4421323),
#  'Camp Ripley (Installation Wide PA) (Western AOI SI)': (42.267, -79.7106)}

# %%
df.loc[df['latitude'].isna(), 'latitude'] = df.loc[df['latitude'].isna(), 'sampling_location'].map(
    lambda x: location_cache.get(x, (None, None))[0]
)

df.loc[df['longitude'].isna(), 'longitude'] = df.loc[df['longitude'].isna(), 'sampling_location'].map(
    lambda x: location_cache.get(x, (None, None))[1]
)

# %%
df
# Out:
#         sample_id                                  sampling_location  \
# 0     YE10039-001                                        Camp Ripley
# 1     YE10039-001                                        Camp Ripley
# 2     YE10039-001                                        Camp Ripley
# 3     YE10039-001                                        Camp Ripley
# 4     YE10039-001                                        Camp Ripley
# ..            ...                                                ...
# 547  410-161204-4  Camp Ripley (Installation Wide PA) (Western AO...
# 548  410-161204-4  Camp Ripley (Installation Wide PA) (Western AO...
# 549  410-161204-4  Camp Ripley (Installation Wide PA) (Western AO...
# 550  410-161204-4  Camp Ripley (Installation Wide PA) (Western AO...
# 551  410-161204-4  Camp Ripley (Installation Wide PA) (Western AO...
#
#     data_source   latitude  longitude sampling_date pws_id water_system_name  \
# 0           DoD  46.202695 -94.442132    2023-05-08    NaN               NaN
# 1           DoD  46.202695 -94.442132    2023-05-08    NaN               NaN
# 2           DoD  46.202695 -94.442132    2023-05-08    NaN               NaN
# 3           DoD  46.202695 -94.442132    2023-05-08    NaN               NaN
# 4           DoD  46.202695 -94.442132    2023-05-08    NaN               NaN
# ..          ...        ...        ...           ...    ...               ...
# 547         DoD  42.267000 -79.710600    2024-02-18    NaN               NaN
# 548         DoD  42.267000 -79.710600    2024-02-18    NaN               NaN
# 549         DoD  42.267000 -79.710600    2024-02-18    NaN               NaN
# 550         DoD  42.267000 -79.710600    2024-02-18    NaN               NaN
# 551         DoD  42.267000 -79.710600    2024-02-18    NaN               NaN
#
#      population well_type  ...  city county MRL   DL analytical_methods  \
# 0           NaN       NaN  ...   NaN    NaN NaN  3.7            QSM_B15
# 1           NaN       NaN  ...   NaN    NaN NaN  1.9            QSM_B15
# 2           NaN       NaN  ...   NaN    NaN NaN  1.9            QSM_B15
# 3           NaN       NaN  ...   NaN    NaN NaN  3.7            QSM_B15
# 4           NaN       NaN  ...   NaN    NaN NaN  1.9            QSM_B15
# ..          ...       ...  ...   ...    ...  ..  ...                ...
# 547         NaN       NaN  ...   NaN    NaN NaN  1.8              537.1
# 548         NaN       NaN  ...   NaN    NaN NaN  0.9              537.1
# 549         NaN       NaN  ...   NaN    NaN NaN  0.9              537.1
# 550         NaN       NaN  ...   NaN    NaN NaN  1.3              537.1
# 551         NaN       NaN  ...   NaN    NaN NaN  0.9              537.1
#
#     is_detected   analyte  concentration pfas_total note
# 0         False   HFPO-DA            0.0        NaN  NaN
# 1          True      PFOS           49.0        NaN  NaN
# 2         False     PFUNA            0.0        NaN  NaN
# 3         False  NMEFOSAA            0.0        NaN  NaN
# 4          True     PFPEA            3.8        NaN  NaN
# ..          ...       ...            ...        ...  ...
# 547         NaN    8:2FTS            0.0        NaN  NaN
# 548         NaN      PFNS            0.0        NaN  NaN
# 549         NaN    PFTRDA            0.0        NaN  NaN
# 550         NaN     PFOSA            1.8        NaN  NaN
# 551         NaN    4:2FTS            0.0        NaN  NaN
#
# [1637 rows x 24 columns]

# %%
df.to_csv('minnesota_dw.csv')

# %%
df
# Out:
#         sample_id                                  sampling_location  \
# 0     YE10039-001                                        Camp Ripley
# 1     YE10039-001                                        Camp Ripley
# 2     YE10039-001                                        Camp Ripley
# 3     YE10039-001                                        Camp Ripley
# 4     YE10039-001                                        Camp Ripley
# ..            ...                                                ...
# 547  410-161204-4  Camp Ripley (Installation Wide PA) (Western AO...
# 548  410-161204-4  Camp Ripley (Installation Wide PA) (Western AO...
# 549  410-161204-4  Camp Ripley (Installation Wide PA) (Western AO...
# 550  410-161204-4  Camp Ripley (Installation Wide PA) (Western AO...
# 551  410-161204-4  Camp Ripley (Installation Wide PA) (Western AO...
#
#     data_source  latitude  longitude sampling_date pws_id water_system_name  \
# 0           DoD       NaN        NaN    2023-05-08    NaN               NaN
# 1           DoD       NaN        NaN    2023-05-08    NaN               NaN
# 2           DoD       NaN        NaN    2023-05-08    NaN               NaN
# 3           DoD       NaN        NaN    2023-05-08    NaN               NaN
# 4           DoD       NaN        NaN    2023-05-08    NaN               NaN
# ..          ...       ...        ...           ...    ...               ...
# 547         DoD       NaN        NaN    2024-02-18    NaN               NaN
# 548         DoD       NaN        NaN    2024-02-18    NaN               NaN
# 549         DoD       NaN        NaN    2024-02-18    NaN               NaN
# 550         DoD       NaN        NaN    2024-02-18    NaN               NaN
# 551         DoD       NaN        NaN    2024-02-18    NaN               NaN
#
#      population well_type  ...  city county MRL   DL analytical_methods  \
# 0           NaN       NaN  ...   NaN    NaN NaN  3.7            QSM_B15
# 1           NaN       NaN  ...   NaN    NaN NaN  1.9            QSM_B15
# 2           NaN       NaN  ...   NaN    NaN NaN  1.9            QSM_B15
# 3           NaN       NaN  ...   NaN    NaN NaN  3.7            QSM_B15
# 4           NaN       NaN  ...   NaN    NaN NaN  1.9            QSM_B15
# ..          ...       ...  ...   ...    ...  ..  ...                ...
# 547         NaN       NaN  ...   NaN    NaN NaN  1.8              537.1
# 548         NaN       NaN  ...   NaN    NaN NaN  0.9              537.1
# 549         NaN       NaN  ...   NaN    NaN NaN  0.9              537.1
# 550         NaN       NaN  ...   NaN    NaN NaN  1.3              537.1
# 551         NaN       NaN  ...   NaN    NaN NaN  0.9              537.1
#
#     is_detected   analyte  concentration pfas_total note
# 0         False   HFPO-DA            0.0        NaN  NaN
# 1          True      PFOS           49.0        NaN  NaN
# 2         False     PFUNA            0.0        NaN  NaN
# 3         False  NMEFOSAA            0.0        NaN  NaN
# 4          True     PFPEA            3.8        NaN  NaN
# ..          ...       ...            ...        ...  ...
# 547         NaN    8:2FTS            0.0        NaN  NaN
# 548         NaN      PFNS            0.0        NaN  NaN
# 549         NaN    PFTRDA            0.0        NaN  NaN
# 550         NaN     PFOSA            1.8        NaN  NaN
# 551         NaN    4:2FTS            0.0        NaN  NaN
#
# [1637 rows x 24 columns]
