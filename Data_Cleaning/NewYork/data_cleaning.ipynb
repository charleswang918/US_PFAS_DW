# %%
import pandas as pd
import camelot
import os
import numpy as np

# %%
os.getcwd()
# Out:
# '/Users/chuqiwang/Documents/US_PFAS_Project/data_cleaning/NewYork'

# %%
ny_df1 = pd.read_excel('Export_Plattsburgh AFB.xlsx')

# %%
ny_df1
# Out:
#       Component ID  Component     State Installation Name Installation Type  \
# 0             5700  Air Force  New York   Plattsburgh AFB              BRAC
# 1             5700  Air Force  New York   Plattsburgh AFB              BRAC
# 2             5700  Air Force  New York   Plattsburgh AFB              BRAC
# 3             5700  Air Force  New York   Plattsburgh AFB              BRAC
# 4             5700  Air Force  New York   Plattsburgh AFB              BRAC
# ...            ...        ...       ...               ...               ...
# 3485          5700  Air Force  New York   Plattsburgh AFB              BRAC
# 3486          5700  Air Force  New York   Plattsburgh AFB              BRAC
# 3487          5700  Air Force  New York   Plattsburgh AFB              BRAC
# 3488          5700  Air Force  New York   Plattsburgh AFB              BRAC
# 3489          5700  Air Force  New York   Plattsburgh AFB              BRAC
#
#      Lab Report Id Laboratory Sample ID Sample Date Analysis Method  \
# 0        320-82218          320-82218-1  11/17/2021           537.1
# 1        320-82218          320-82218-1  11/17/2021           537.1
# 2        320-82218          320-82218-1  11/17/2021           537.1
# 3        320-82218          320-82218-1  11/17/2021           537.1
# 4        320-82218          320-82218-1  11/17/2021           537.1
# ...            ...                  ...         ...             ...
# 3485    410-164477         410-164477-4   3/17/2024            1633
# 3486    410-164477         410-164477-4   3/17/2024            1633
# 3487    410-164477         410-164477-4   3/17/2024            1633
# 3488    410-164477         410-164477-4   3/17/2024            1633
# 3489    410-164477         410-164477-4   3/17/2024            1633
#
#        CAS Number Analyte Abbreviation  Final Result  Limit of Detection  \
# 0        375-73-5                 PFBS          21.0                 1.5
# 1        375-85-9                PFHpA          15.0                 1.5
# 2        355-46-4                PFHxS          52.0                 1.5
# 3        375-95-1                 PFNA           2.5                 1.5
# 4       1763-23-1                 PFOS          98.0                 1.5
# ...           ...                  ...           ...                 ...
# 3485   79780-39-5                PFDoS           NaN                 1.9
# 3486     812-70-4              7:3FTCA           NaN                25.0
# 3487  863090-89-5                PFMBA           NaN                 2.0
# 3488  914637-49-3              5:3FTCA           NaN                25.0
# 3489  919005-14-4                ADONA           NaN                 3.8
#
#      Final Units Final Qualification Treatment System Pre Or Post Treatment
# 0           ng/L                 NaN              Yes         pre-treatment
# 1           ng/L                 NaN              Yes         pre-treatment
# 2           ng/L                 NaN              Yes         pre-treatment
# 3           ng/L                 NaN              Yes         pre-treatment
# 4           ng/L                 NaN              Yes         pre-treatment
# ...          ...                 ...              ...                   ...
# 3485        ng/L                   U              Yes         pre-treatment
# 3486        ng/L                   U              Yes         pre-treatment
# 3487        ng/L                   U              Yes         pre-treatment
# 3488        ng/L                   U              Yes         pre-treatment
# 3489        ng/L                   U              Yes         pre-treatment
#
# [3490 rows x 17 columns]

# %%
columns = {
    'sample_id': str,
    'sampling_location': str,
    'data_source': str,
    'latitude': float,
    'longitude': float,
    'sampling_date': 'datetime64[ns]',
    'pws_id': str,
    'water_system_name': str,
    'population': int,
    'well_type': str,
    'well_depth': float,
    'units': str,
    'source_type': str,
    'state': str,
    'city': str,
    'county': str,
    'MRL': float,
    'DL': float,
    'analytical_methods': str,
    'is_detected': bool,
    'analyte': str,
    'concentration': float,
    'pfas_total': float,
    'note': str   
}

# %%
df1 = pd.DataFrame({col: pd.Series(dtype=dt) for col, dt in columns.items()})

# %%
df1['analyte'] = ny_df1['Analyte Abbreviation'].str.upper()
df1['concentration'] = ny_df1['Final Result'].fillna(0)
df1['sampling_location'] = ny_df1['Installation Name']
df1['DL'] = ny_df1['Limit of Detection']
df1['sampling_date'] = pd.to_datetime(ny_df1['Sample Date'])
df1['sample_id'] = ny_df1['Laboratory Sample ID']
df1['units'] = ny_df1['Final Units']
df1['state'] = ny_df1['State']
df1['analytical_methods'] = ny_df1['Analysis Method']
df1['data_source'] = 'DoD'
df1['source_type'] = 'drinking water'

# %%
df1['is_detected'] = df1['concentration'] != 0

# %%
df1
# Out:
#          sample_id sampling_location data_source  latitude  longitude  \
# 0      320-82218-1   Plattsburgh AFB         DoD       NaN        NaN
# 1      320-82218-1   Plattsburgh AFB         DoD       NaN        NaN
# 2      320-82218-1   Plattsburgh AFB         DoD       NaN        NaN
# 3      320-82218-1   Plattsburgh AFB         DoD       NaN        NaN
# 4      320-82218-1   Plattsburgh AFB         DoD       NaN        NaN
# ...            ...               ...         ...       ...        ...
# 3485  410-164477-4   Plattsburgh AFB         DoD       NaN        NaN
# 3486  410-164477-4   Plattsburgh AFB         DoD       NaN        NaN
# 3487  410-164477-4   Plattsburgh AFB         DoD       NaN        NaN
# 3488  410-164477-4   Plattsburgh AFB         DoD       NaN        NaN
# 3489  410-164477-4   Plattsburgh AFB         DoD       NaN        NaN
#
#      sampling_date pws_id water_system_name  population well_type  ...  city  \
# 0       2021-11-17    NaN               NaN         NaN       NaN  ...   NaN
# 1       2021-11-17    NaN               NaN         NaN       NaN  ...   NaN
# 2       2021-11-17    NaN               NaN         NaN       NaN  ...   NaN
# 3       2021-11-17    NaN               NaN         NaN       NaN  ...   NaN
# 4       2021-11-17    NaN               NaN         NaN       NaN  ...   NaN
# ...            ...    ...               ...         ...       ...  ...   ...
# 3485    2024-03-17    NaN               NaN         NaN       NaN  ...   NaN
# 3486    2024-03-17    NaN               NaN         NaN       NaN  ...   NaN
# 3487    2024-03-17    NaN               NaN         NaN       NaN  ...   NaN
# 3488    2024-03-17    NaN               NaN         NaN       NaN  ...   NaN
# 3489    2024-03-17    NaN               NaN         NaN       NaN  ...   NaN
#
#      county MRL    DL analytical_methods is_detected  analyte  concentration  \
# 0       NaN NaN   1.5              537.1        True     PFBS           21.0
# 1       NaN NaN   1.5              537.1        True    PFHPA           15.0
# 2       NaN NaN   1.5              537.1        True    PFHXS           52.0
# 3       NaN NaN   1.5              537.1        True     PFNA            2.5
# 4       NaN NaN   1.5              537.1        True     PFOS           98.0
# ...     ...  ..   ...                ...         ...      ...            ...
# 3485    NaN NaN   1.9               1633       False    PFDOS            0.0
# 3486    NaN NaN  25.0               1633       False  7:3FTCA            0.0
# 3487    NaN NaN   2.0               1633       False    PFMBA            0.0
# 3488    NaN NaN  25.0               1633       False  5:3FTCA            0.0
# 3489    NaN NaN   3.8               1633       False    ADONA            0.0
#
#      pfas_total  note
# 0           NaN   NaN
# 1           NaN   NaN
# 2           NaN   NaN
# 3           NaN   NaN
# 4           NaN   NaN
# ...         ...   ...
# 3485        NaN   NaN
# 3486        NaN   NaN
# 3487        NaN   NaN
# 3488        NaN   NaN
# 3489        NaN   NaN
#
# [3490 rows x 24 columns]

# %%
df = df1

# %%
from concurrent.futures import ThreadPoolExecutor
import pandas as pd
from geopy.geocoders import OpenCage

geolocator = OpenCage(api_key="1f1adf3211e64148bfe6de5e054906f8")

def geocode_address(address):
    try:
        location = geolocator.geocode(address)
        if location:
            return (address, location.latitude, location.longitude)
        else:
            return (address, None, None)
    except Exception as e:
        print(f"Error geocoding {address}: {e}")
        return (address, None, None)

addresses_to_query = df.loc[df['latitude'].isna() | df['longitude'].isna(), 'sampling_location'].unique()

with ThreadPoolExecutor(max_workers=10) as executor:
    results = list(executor.map(geocode_address, addresses_to_query))

location_cache = {address: (lat, lon) for address, lat, lon in results}

# %%
location_cache
# Out:
# {'Plattsburgh AFB': (44.671896, -73.450901)}

# %%
df.to_csv('newyork_dw.csv')
