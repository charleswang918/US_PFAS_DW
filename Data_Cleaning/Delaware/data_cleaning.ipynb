# %%
import pandas as pd
import os
import numpy as np

# %%
os.getcwd()
# Out:
# '/Users/chuqiwang/Desktop/US_PFAS_Project/Delaware'

# %%
de_df1 = pd.read_excel('Export_Dover AFB.xlsx')

# %%
de_df1
# Out:
#       Component ID  Component     State Installation Name Installation Type  \
# 0             5700  Air Force  Delaware         Dover AFB            Active
# 1             5700  Air Force  Delaware         Dover AFB            Active
# 2             5700  Air Force  Delaware         Dover AFB            Active
# 3             5700  Air Force  Delaware         Dover AFB            Active
# 4             5700  Air Force  Delaware         Dover AFB            Active
# ...            ...        ...       ...               ...               ...
# 1003          5700  Air Force  Delaware         Dover AFB            Active
# 1004          5700  Air Force  Delaware         Dover AFB            Active
# 1005          5700  Air Force  Delaware         Dover AFB            Active
# 1006          5700  Air Force  Delaware         Dover AFB            Active
# 1007          5700  Air Force  Delaware         Dover AFB            Active
#
# ...

# %%
columns = {
    'sample_id': str,
    'sampling_location': str,
    'data_source': str,
    'latitude': float,
    'longitude': float,
    'sampling_date': 'datetime64[ns]',
    'pws_id': str,
    'water_system_name': str,
    'population': int,
    'well_type': str,
    'well_depth': float,
    'units': str,
    'source_type': str,
    'state': str,
    'city': str,
    'county': str,
    'MRL': float,
    'DL': float,
    'analytical_methods': str,
    'is_detected': bool,
    'analyte': str,
    'concentration': float,
    'pfas_total': float,
    'note': str   
}

# %%
df1 = pd.DataFrame({col: pd.Series(dtype=dt) for col, dt in columns.items()})
df1['analyte'] = de_df1['Analyte Abbreviation'].str.upper()
df1['concentration'] = de_df1['Final Result'].fillna(0)
df1['sampling_location'] = de_df1['Installation Name']
df1['DL'] = de_df1['Limit of Detection']
df1['sampling_date'] = pd.to_datetime(de_df1['Sample Date'])
df1['sample_id'] = de_df1['Laboratory Sample ID']
df1['units'] = de_df1['Final Units']
df1['state'] = de_df1['State']
df1['analytical_methods'] = de_df1['Analysis Method']
df1['data_source'] = 'DoD'
df1['source_type'] = 'drinking water'

# %%
df1['is_detected'] = df1['concentration'] != 0

# %%
df1
# Out:
#        sample_id sampling_location data_source  latitude  longitude  \
# 0     2201216-10         Dover AFB         DoD       NaN        NaN
# 1     2201216-10         Dover AFB         DoD       NaN        NaN
# 2     2201216-10         Dover AFB         DoD       NaN        NaN
# 3     2201216-10         Dover AFB         DoD       NaN        NaN
# 4     2201216-10         Dover AFB         DoD       NaN        NaN
# ...          ...               ...         ...       ...        ...
# 1003   FC14518-6         Dover AFB         DoD       NaN        NaN
# 1004   FC14518-6         Dover AFB         DoD       NaN        NaN
# 1005   FC14518-6         Dover AFB         DoD       NaN        NaN
# 1006   FC14518-6         Dover AFB         DoD       NaN        NaN
# 1007   FC14518-6         Dover AFB         DoD       NaN        NaN
#
#      sampling_date pws_id water_system_name  population well_type  ...  city  \
# ...

# %%
df1.to_csv('delaware_dw.csv')
