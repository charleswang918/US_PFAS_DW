# %%
import pandas as pd
import os
import numpy as np

# %%
os.getcwd()
# Out:
# '/Users/chuqiwang/Desktop/US_PFAS_Project/Texas'

# %%
tx_df1 = pd.read_excel('Export_Sheppard AFB.xlsx')

# %%
tx_df1
# Out:
#      Component ID  Component  State Installation Name Installation Type  \
# 0            5700  Air Force  Texas      Sheppard AFB            Active
# 1            5700  Air Force  Texas      Sheppard AFB            Active
# 2            5700  Air Force  Texas      Sheppard AFB            Active
# 3            5700  Air Force  Texas      Sheppard AFB            Active
# 4            5700  Air Force  Texas      Sheppard AFB            Active
# ..            ...        ...    ...               ...               ...
# 306          5700  Air Force  Texas      Sheppard AFB            Active
# 307          5700  Air Force  Texas      Sheppard AFB            Active
# 308          5700  Air Force  Texas      Sheppard AFB            Active
# 309          5700  Air Force  Texas      Sheppard AFB            Active
# 310          5700  Air Force  Texas      Sheppard AFB            Active
#
#     Lab Report Id Laboratory Sample ID Sample Date Analysis Method  \
# ...

# %%
columns = {
    'sample_id': str,
    'sampling_location': str,
    'data_source': str,
    'latitude': float,
    'longitude': float,
    'sampling_date': 'datetime64[ns]',
    'pws_id': str,
    'water_system_name': str,
    'population': int,
    'well_type': str,
    'well_depth': float,
    'units': str,
    'source_type': str,
    'state': str,
    'city': str,
    'county': str,
    'MRL': float,
    'DL': float,
    'analytical_methods': str,
    'is_detected': bool,
    'analyte': str,
    'concentration': float,
    'pfas_total': float,
    'note': str   
}

# %%
df1 = pd.DataFrame({col: pd.Series(dtype=dt) for col, dt in columns.items()})

# %%
df1['analyte'] = tx_df1['Analyte Abbreviation'].str.upper()
df1['concentration'] = tx_df1['Final Result'].fillna(0)
df1['sampling_location'] = tx_df1['Installation Name']
df1['DL'] = tx_df1['Limit of Detection']
df1['sampling_date'] = pd.to_datetime(tx_df1['Sample Date'])
df1['sample_id'] = tx_df1['Laboratory Sample ID']
df1['units'] = tx_df1['Final Units']
df1['state'] = tx_df1['State']
df1['analytical_methods'] = tx_df1['Analysis Method']
df1['data_source'] = 'DoD'
df1['source_type'] = 'drinking water'

# %%
df1['is_detected'] = df1['concentration'] != 0

# %%
tx_df2 = pd.read_excel('Export_Joint Base San Antonio - Lackland, Randolph, Ft Sam Houston, Camp Bullis.xlsx')

# %%
tx_df2
# Out:
#       Component ID  Component  State  \
# 0             5700  Air Force  Texas
# 1             5700  Air Force  Texas
# 2             5700  Air Force  Texas
# 3             5700  Air Force  Texas
# 4             5700  Air Force  Texas
# ...            ...        ...    ...
# 2491          5700  Air Force  Texas
# 2492          5700  Air Force  Texas
# 2493          5700  Air Force  Texas
# 2494          5700  Air Force  Texas
# 2495          5700  Air Force  Texas
#
#                                       Installation Name Installation Type  \
# 0     Joint Base San Antonio - Lackland, Randolph, F...            Active
# 1     Joint Base San Antonio - Lackland, Randolph, F...            Active
# 2     Joint Base San Antonio - Lackland, Randolph, F...            Active
# 3     Joint Base San Antonio - Lackland, Randolph, F...            Active
# 4     Joint Base San Antonio - Lackland, Randolph, F...            Active
# ...

# %%
df2 = pd.DataFrame({col: pd.Series(dtype=dt) for col, dt in columns.items()})

# %%
df2['analyte'] = tx_df2['Analyte Abbreviation'].str.upper()
df2['concentration'] = tx_df2['Final Result'].fillna(0)
df2['sampling_location'] = tx_df2['Installation Name']
df2['DL'] = tx_df2['Limit of Detection']
df2['sampling_date'] = pd.to_datetime(tx_df2['Sample Date'])
df2['sample_id'] = tx_df2['Laboratory Sample ID']
df2['units'] = tx_df2['Final Units']
df2['state'] = tx_df2['State']
df2['analytical_methods'] = tx_df2['Analysis Method']
df2['data_source'] = 'DoD'
df2['source_type'] = 'drinking water'

# %%
df2['is_detected'] = df2['concentration'] != 0

# %%
df2
# Out:
#       sample_id                                  sampling_location  \
# 0     FA94283-1  Joint Base San Antonio - Lackland, Randolph, F...
# 1     FA94283-1  Joint Base San Antonio - Lackland, Randolph, F...
# 2     FA94283-1  Joint Base San Antonio - Lackland, Randolph, F...
# 3     FA94283-1  Joint Base San Antonio - Lackland, Randolph, F...
# 4     FA94283-1  Joint Base San Antonio - Lackland, Randolph, F...
# ...         ...                                                ...
# 2491  FC14532-1  Joint Base San Antonio - Lackland, Randolph, F...
# 2492  FC14532-1  Joint Base San Antonio - Lackland, Randolph, F...
# 2493  FC14532-1  Joint Base San Antonio - Lackland, Randolph, F...
# 2494  FC14532-1  Joint Base San Antonio - Lackland, Randolph, F...
# 2495  FC14532-1  Joint Base San Antonio - Lackland, Randolph, F...
#
#      data_source  latitude  longitude sampling_date pws_id water_system_name  \
# 0            DoD       NaN        NaN    2022-03-22    NaN               NaN
# ...

# %%
tx_df3 = pd.read_excel('Export_Goodfellow AFB.xlsx')

# %%
tx_df3
# Out:
#        Component ID  Component  State Installation Name Installation Type  \
# 0              5700  Air Force  Texas    Goodfellow AFB            Active
# 1              5700  Air Force  Texas    Goodfellow AFB            Active
# 2              5700  Air Force  Texas    Goodfellow AFB            Active
# 3              5700  Air Force  Texas    Goodfellow AFB            Active
# 4              5700  Air Force  Texas    Goodfellow AFB            Active
# ...             ...        ...    ...               ...               ...
# 13603          5700  Air Force  Texas    Goodfellow AFB            Active
# 13604          5700  Air Force  Texas    Goodfellow AFB            Active
# 13605          5700  Air Force  Texas    Goodfellow AFB            Active
# 13606          5700  Air Force  Texas    Goodfellow AFB            Active
# 13607          5700  Air Force  Texas    Goodfellow AFB            Active
#
#       Lab Report Id Laboratory Sample ID Sample Date Analysis Method  \
# ...

# %%
df3 = pd.DataFrame({col: pd.Series(dtype=dt) for col, dt in columns.items()})

# %%
df3['analyte'] = tx_df3['Analyte Abbreviation'].str.upper()
df3['concentration'] = tx_df3['Final Result'].fillna(0)
df3['sampling_location'] = tx_df3['Installation Name']
df3['DL'] = tx_df3['Limit of Detection']
df3['sampling_date'] = pd.to_datetime(tx_df3['Sample Date'])
df3['sample_id'] = tx_df3['Laboratory Sample ID']
df3['units'] = tx_df3['Final Units']
df3['state'] = tx_df3['State']
df3['analytical_methods'] = tx_df3['Analysis Method']
df3['data_source'] = 'DoD'
df3['source_type'] = 'drinking water'

# %%
df3['is_detected'] = df3['concentration'] != 0

# %%
df3
# Out:
#        sample_id sampling_location data_source  latitude  longitude  \
# 0      FA94272-2    Goodfellow AFB         DoD       NaN        NaN
# 1      FA94272-2    Goodfellow AFB         DoD       NaN        NaN
# 2      FA94272-2    Goodfellow AFB         DoD       NaN        NaN
# 3      FA94272-2    Goodfellow AFB         DoD       NaN        NaN
# 4      FA94272-2    Goodfellow AFB         DoD       NaN        NaN
# ...          ...               ...         ...       ...        ...
# 13603  FC14066-9    Goodfellow AFB         DoD       NaN        NaN
# 13604  FC14066-9    Goodfellow AFB         DoD       NaN        NaN
# 13605  FC14066-9    Goodfellow AFB         DoD       NaN        NaN
# 13606  FC14066-9    Goodfellow AFB         DoD       NaN        NaN
# 13607  FC14066-9    Goodfellow AFB         DoD       NaN        NaN
#
#       sampling_date pws_id water_system_name  population well_type  ...  city  \
# ...

# %%
tx_df4 = pd.read_excel('Export_Dyess AFB.xlsx')

# %%
tx_df4
# Out:
#     Component ID  Component  State Installation Name Installation Type  \
# 0           5700  Air Force  Texas         Dyess AFB            Active
# 1           5700  Air Force  Texas         Dyess AFB            Active
# 2           5700  Air Force  Texas         Dyess AFB            Active
# 3           5700  Air Force  Texas         Dyess AFB            Active
# 4           5700  Air Force  Texas         Dyess AFB            Active
# 5           5700  Air Force  Texas         Dyess AFB            Active
# 6           5700  Air Force  Texas         Dyess AFB            Active
# 7           5700  Air Force  Texas         Dyess AFB            Active
# 8           5700  Air Force  Texas         Dyess AFB            Active
# 9           5700  Air Force  Texas         Dyess AFB            Active
# 10          5700  Air Force  Texas         Dyess AFB            Active
# 11          5700  Air Force  Texas         Dyess AFB            Active
# ...

# %%
df4 = pd.DataFrame({col: pd.Series(dtype=dt) for col, dt in columns.items()})

# %%
df4['analyte'] = tx_df4['Analyte Abbreviation'].str.upper()
df4['concentration'] = tx_df4['Final Result'].fillna(0)
df4['sampling_location'] = tx_df4['Installation Name']
df4['DL'] = tx_df4['Limit of Detection']
df4['sampling_date'] = pd.to_datetime(tx_df4['Sample Date'])
df4['sample_id'] = tx_df4['Laboratory Sample ID']
df4['units'] = tx_df4['Final Units']
df4['state'] = tx_df4['State']
df4['analytical_methods'] = tx_df4['Analysis Method']
df4['data_source'] = 'DoD'
df4['source_type'] = 'drinking water'

# %%
df4['is_detected'] = df4['concentration'] != 0

# %%
df4
# Out:
#     sample_id sampling_location data_source  latitude  longitude  \
# 0   FA90728-1         Dyess AFB         DoD       NaN        NaN
# 1   FA90728-1         Dyess AFB         DoD       NaN        NaN
# 2   FA90728-1         Dyess AFB         DoD       NaN        NaN
# 3   FA90728-1         Dyess AFB         DoD       NaN        NaN
# 4   FA90728-1         Dyess AFB         DoD       NaN        NaN
# 5   FA90728-1         Dyess AFB         DoD       NaN        NaN
# 6   FA90728-1         Dyess AFB         DoD       NaN        NaN
# 7   FA90728-1         Dyess AFB         DoD       NaN        NaN
# 8   FA90728-1         Dyess AFB         DoD       NaN        NaN
# 9   FA90728-1         Dyess AFB         DoD       NaN        NaN
# 10  FA90728-1         Dyess AFB         DoD       NaN        NaN
# 11  FA90728-1         Dyess AFB         DoD       NaN        NaN
# 12  FA90728-1         Dyess AFB         DoD       NaN        NaN
# ...

# %%
tx_df5 = pd.read_excel('Export_Reese AFB.xlsx')

# %%
tx_df5
# Out:
#         Component ID  Component  State Installation Name Installation Type  \
# 0               5700  Air Force  Texas         Reese AFB              BRAC
# 1               5700  Air Force  Texas         Reese AFB              BRAC
# 2               5700  Air Force  Texas         Reese AFB              BRAC
# 3               5700  Air Force  Texas         Reese AFB              BRAC
# 4               5700  Air Force  Texas         Reese AFB              BRAC
# ...              ...        ...    ...               ...               ...
# 122818          5700  Air Force  Texas         Reese AFB              BRAC
# 122819          5700  Air Force  Texas         Reese AFB              BRAC
# 122820          5700  Air Force  Texas         Reese AFB              BRAC
# 122821          5700  Air Force  Texas         Reese AFB              BRAC
# 122822          5700  Air Force  Texas         Reese AFB              BRAC
#
# ...

# %%
df5 = pd.DataFrame({col: pd.Series(dtype=dt) for col, dt in columns.items()})

# %%
df5['analyte'] = tx_df5['Analyte Abbreviation'].str.upper()
df5['concentration'] = tx_df5['Final Result'].fillna(0)
df5['sampling_location'] = tx_df5['Installation Name']
df5['DL'] = tx_df5['Limit of Detection']
df5['sampling_date'] = pd.to_datetime(tx_df5['Sample Date'])
df5['sample_id'] = tx_df5['Laboratory Sample ID']
df5['units'] = tx_df5['Final Units']
df5['state'] = tx_df5['State']
df5['analytical_methods'] = tx_df5['Analysis Method']
df5['data_source'] = 'DoD'
df5['source_type'] = 'drinking water'

# %%
df5['is_detected'] = df5['concentration'] != 0

# %%
df5
# Out:
#         sample_id sampling_location data_source  latitude  longitude  \
# 0       FA95465-1         Reese AFB         DoD       NaN        NaN
# 1       FA95465-1         Reese AFB         DoD       NaN        NaN
# 2       FA95465-1         Reese AFB         DoD       NaN        NaN
# 3       FA95465-1         Reese AFB         DoD       NaN        NaN
# 4       FA95465-1         Reese AFB         DoD       NaN        NaN
# ...           ...               ...         ...       ...        ...
# 122818  FC14392-5         Reese AFB         DoD       NaN        NaN
# 122819  FC14392-5         Reese AFB         DoD       NaN        NaN
# 122820  FC14392-5         Reese AFB         DoD       NaN        NaN
# 122821  FC14392-5         Reese AFB         DoD       NaN        NaN
# 122822  FC14392-5         Reese AFB         DoD       NaN        NaN
#
#        sampling_date pws_id water_system_name  population well_type  ...  \
# ...

# %%
df = pd.concat([df1, df2, df3, df4, df5])

# %%
df.index = range(0, len(df))

# %%
df
# Out:
#         sample_id sampling_location data_source  latitude  longitude  \
# 0       FA91320-1      Sheppard AFB         DoD       NaN        NaN
# 1       FA91320-1      Sheppard AFB         DoD       NaN        NaN
# 2       FA91320-1      Sheppard AFB         DoD       NaN        NaN
# 3       FA91320-1      Sheppard AFB         DoD       NaN        NaN
# 4       FA91320-1      Sheppard AFB         DoD       NaN        NaN
# ...           ...               ...         ...       ...        ...
# 139281  FC14392-5         Reese AFB         DoD       NaN        NaN
# 139282  FC14392-5         Reese AFB         DoD       NaN        NaN
# 139283  FC14392-5         Reese AFB         DoD       NaN        NaN
# 139284  FC14392-5         Reese AFB         DoD       NaN        NaN
# 139285  FC14392-5         Reese AFB         DoD       NaN        NaN
#
#        sampling_date pws_id water_system_name  population well_type  ...  \
# ...

# %%
df.to_csv('texas_dw.csv')

# %%
# denix_table = pd.read_csv('../Montana/output.csv')

# %%
# denix_table['analyte'] = denix_table['Analyte Name'].apply(lambda x: x.split()[-1]).str.replace(r'[()]', '', regex=True).str.upper()
# denix_table['Result'] = denix_table['Result'].str.replace(' ', '')
# denix_table['Reporting Limit'] = denix_table['Reporting Limit'].str.replace(' ','')

# %%
# denix_table.to_csv('../denix.csv')

# %%
# denix_table[denix_table['State'] == 'TX']
# Out:
#                   Location Name State         Water System Name  \
# 2033         US, TX, Camp Bow e    TX  Camp Bow e-Musgrave(FED)
# 2034         US, TX, Camp Bow e    TX  Camp Bow e-Musgrave(FED)
# 2035         US, TX, Camp Bow e    TX  Camp Bow e-Musgrave(FED)
# 2036         US, TX, Camp Bow e    TX  Camp Bow e-Musgrave(FED)
# 2037         US, TX, Camp Bow e    TX  Camp Bow e-Musgrave(FED)
# ...                         ...   ...                       ...
# 6189  US, TX, El Campo TNG Si e    TX    El Campo Training S te
# 6190  US, TX, El Campo TNG Si e    TX    El Campo Training S te
# 6191  US, TX, El Campo TNG Si e    TX    El Campo Training S te
# 6192  US, TX, El Campo TNG Si e    TX    El Campo Training S te
# 6193  US, TX, El Campo TNG Si e    TX    El Campo Training S te
#
#         Component Name     Sample Date Time  \
# 2033  Camp Bowie-WWPO1  0 /11/2017 08:15:00
# 2034  Camp Bowie-WWPO1  0 /11/2017 08:15:00
# 2035  Camp Bowie-WWPO1  0 /11/2017 08:15:00
# ...
