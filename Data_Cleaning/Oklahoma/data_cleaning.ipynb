# %%
import pandas as pd
import os
import numpy as np

# %%
os.getcwd()
# Out:
# '/Users/chuqiwang/Desktop/US_PFAS_Project/Oklahoma'

# %%
ok_df1 = pd.read_excel('Export_Tinker AFB.xlsx')

# %%
ok_df1
# Out:
#       Component ID  Component     State Installation Name Installation Type  \
# 0             5700  Air Force  Oklahoma        Tinker AFB            Active
# 1             5700  Air Force  Oklahoma        Tinker AFB            Active
# 2             5700  Air Force  Oklahoma        Tinker AFB            Active
# 3             5700  Air Force  Oklahoma        Tinker AFB            Active
# 4             5700  Air Force  Oklahoma        Tinker AFB            Active
# ...            ...        ...       ...               ...               ...
# 1315          5700  Air Force  Oklahoma        Tinker AFB            Active
# 1316          5700  Air Force  Oklahoma        Tinker AFB            Active
# 1317          5700  Air Force  Oklahoma        Tinker AFB            Active
# 1318          5700  Air Force  Oklahoma        Tinker AFB            Active
# 1319          5700  Air Force  Oklahoma        Tinker AFB            Active
#
# ...

# %%
columns = {
    'sample_id': str,
    'sampling_location': str,
    'data_source': str,
    'latitude': float,
    'longitude': float,
    'sampling_date': 'datetime64[ns]',
    'pws_id': str,
    'water_system_name': str,
    'population': int,
    'well_type': str,
    'well_depth': float,
    'units': str,
    'source_type': str,
    'state': str,
    'city': str,
    'county': str,
    'MRL': float,
    'DL': float,
    'analytical_methods': str,
    'is_detected': bool,
    'analyte': str,
    'concentration': float,
    'pfas_total': float,
    'note': str   
}

# %%
df1 = pd.DataFrame({col: pd.Series(dtype=dt) for col, dt in columns.items()})
df1['analyte'] = ok_df1['Analyte Abbreviation'].str.upper()
df1['concentration'] = ok_df1['Final Result'].fillna(0)
df1['sampling_location'] = ok_df1['Installation Name']
df1['DL'] = ok_df1['Limit of Detection']
df1['sampling_date'] = pd.to_datetime(ok_df1['Sample Date'])
df1['sample_id'] = ok_df1['Laboratory Sample ID']
df1['units'] = ok_df1['Final Units']
df1['state'] = ok_df1['State']
df1['analytical_methods'] = ok_df1['Analysis Method']
df1['data_source'] = 'DoD'
df1['source_type'] = 'drinking water'

# %%
df1['is_detected'] = df1['concentration'] != 0

# %%
df1
# Out:
#       sample_id sampling_location data_source  latitude  longitude  \
# 0     FA92616-1        Tinker AFB         DoD       NaN        NaN
# 1     FA92616-1        Tinker AFB         DoD       NaN        NaN
# 2     FA92616-1        Tinker AFB         DoD       NaN        NaN
# 3     FA92616-1        Tinker AFB         DoD       NaN        NaN
# 4     FA92616-1        Tinker AFB         DoD       NaN        NaN
# ...         ...               ...         ...       ...        ...
# 1315  FC14553-5        Tinker AFB         DoD       NaN        NaN
# 1316  FC14553-5        Tinker AFB         DoD       NaN        NaN
# 1317  FC14553-5        Tinker AFB         DoD       NaN        NaN
# 1318  FC14553-5        Tinker AFB         DoD       NaN        NaN
# 1319  FC14553-5        Tinker AFB         DoD       NaN        NaN
#
#      sampling_date pws_id water_system_name  population well_type  ...  city  \
# 0       2022-01-24    NaN               NaN         NaN       NaN  ...   NaN
# ...

# %%
df1.to_csv('oklahoma_dw.csv')
