# %%
import pandas as pd
import os
import numpy as np

# %%
os.getcwd()
# Out:
# '/Users/chuqiwang/Desktop/US_PFAS_Project/RhodeIsland'

# %%
ri_df1 = pd.read_excel('Export_NAVAL AUX LANDING FIELD.xlsx')

# %%
ri_df1
# Out:
#       Component ID Component         State        Installation Name  \
# 0             9799      FUDS  Rhode Island  NAVAL AUX LANDING FIELD
# 1             9799      FUDS  Rhode Island  NAVAL AUX LANDING FIELD
# 2             9799      FUDS  Rhode Island  NAVAL AUX LANDING FIELD
# 3             9799      FUDS  Rhode Island  NAVAL AUX LANDING FIELD
# 4             9799      FUDS  Rhode Island  NAVAL AUX LANDING FIELD
# ...            ...       ...           ...                      ...
# 4177          9799      FUDS  Rhode Island  NAVAL AUX LANDING FIELD
# 4178          9799      FUDS  Rhode Island  NAVAL AUX LANDING FIELD
# 4179          9799      FUDS  Rhode Island  NAVAL AUX LANDING FIELD
# 4180          9799      FUDS  Rhode Island  NAVAL AUX LANDING FIELD
# 4181          9799      FUDS  Rhode Island  NAVAL AUX LANDING FIELD
#
#      Installation Type          Lab Report Id Laboratory Sample ID  \
# 0                 FUDS                M2E1227           M2E1227-01
# ...

# %%
columns = {
    'sample_id': str,
    'sampling_location': str,
    'data_source': str,
    'latitude': float,
    'longitude': float,
    'sampling_date': 'datetime64[ns]',
    'pws_id': str,
    'water_system_name': str,
    'population': int,
    'well_type': str,
    'well_depth': float,
    'units': str,
    'source_type': str,
    'state': str,
    'city': str,
    'county': str,
    'MRL': float,
    'DL': float,
    'analytical_methods': str,
    'is_detected': bool,
    'analyte': str,
    'concentration': float,
    'pfas_total': float,
    'note': str   
}

# %%
df1 = pd.DataFrame({col: pd.Series(dtype=dt) for col, dt in columns.items()})
df1['analyte'] = ri_df1['Analyte Abbreviation'].str.upper()
df1['concentration'] = ri_df1['Final Result'].fillna(0)
df1['sampling_location'] = ri_df1['Installation Name']
df1['DL'] = ri_df1['Limit of Detection']
df1['sampling_date'] = pd.to_datetime(ri_df1['Sample Date'])
df1['sample_id'] = ri_df1['Laboratory Sample ID']
df1['units'] = ri_df1['Final Units']
df1['state'] = ri_df1['State']
df1['analytical_methods'] = ri_df1['Analysis Method']
df1['data_source'] = 'DoD'
df1['source_type'] = 'drinking water'

# %%
df1['is_detected'] = df1['concentration'] != 0

# %%
df1
# Out:
#          sample_id        sampling_location data_source  latitude  longitude  \
# 0       M2E1227-01  NAVAL AUX LANDING FIELD         DoD       NaN        NaN
# 1       M2E1227-01  NAVAL AUX LANDING FIELD         DoD       NaN        NaN
# 2       M2E1227-01  NAVAL AUX LANDING FIELD         DoD       NaN        NaN
# 3       M2E1227-01  NAVAL AUX LANDING FIELD         DoD       NaN        NaN
# 4       M2E1227-01  NAVAL AUX LANDING FIELD         DoD       NaN        NaN
# ...            ...                      ...         ...       ...        ...
# 4177  410-143102-1  NAVAL AUX LANDING FIELD         DoD       NaN        NaN
# 4178  410-143102-1  NAVAL AUX LANDING FIELD         DoD       NaN        NaN
# 4179  410-143102-1  NAVAL AUX LANDING FIELD         DoD       NaN        NaN
# 4180  410-143102-1  NAVAL AUX LANDING FIELD         DoD       NaN        NaN
# 4181  410-143102-1  NAVAL AUX LANDING FIELD         DoD       NaN        NaN
#
# ...

# %%
df1.to_csv('rhodeisland_dw.csv')
