# %%
import pandas as pd
import os
import numpy as np

# %%
os.getcwd()
# Out:
# '/Users/chuqiwang/Desktop/US_PFAS_Project/SouthDakota'

# %%
sd_df1 = pd.read_excel('Export_Ellsworth AFB.xlsx')

# %%
sd_df1
# Out:
#       Component ID  Component         State Installation Name  \
# 0             5700  Air Force  South Dakota     Ellsworth AFB
# 1             5700  Air Force  South Dakota     Ellsworth AFB
# 2             5700  Air Force  South Dakota     Ellsworth AFB
# 3             5700  Air Force  South Dakota     Ellsworth AFB
# 4             5700  Air Force  South Dakota     Ellsworth AFB
# ...            ...        ...           ...               ...
# 3307          5700  Air Force  South Dakota     Ellsworth AFB
# 3308          5700  Air Force  South Dakota     Ellsworth AFB
# 3309          5700  Air Force  South Dakota     Ellsworth AFB
# 3310          5700  Air Force  South Dakota     Ellsworth AFB
# 3311          5700  Air Force  South Dakota     Ellsworth AFB
#
#      Installation Type  Lab Report Id  Laboratory Sample ID Sample Date  \
# 0               Active         573149             573149004   3/13/2022
# 1               Active         573149             573149004   3/13/2022
# ...

# %%
columns = {
    'sample_id': str,
    'sampling_location': str,
    'data_source': str,
    'latitude': float,
    'longitude': float,
    'sampling_date': 'datetime64[ns]',
    'pws_id': str,
    'water_system_name': str,
    'population': int,
    'well_type': str,
    'well_depth': float,
    'units': str,
    'source_type': str,
    'state': str,
    'city': str,
    'county': str,
    'MRL': float,
    'DL': float,
    'analytical_methods': str,
    'is_detected': bool,
    'analyte': str,
    'concentration': float,
    'pfas_total': float,
    'note': str   
}

# %%
df1 = pd.DataFrame({col: pd.Series(dtype=dt) for col, dt in columns.items()})
df1['analyte'] = sd_df1['Analyte Abbreviation'].str.upper()
df1['concentration'] = sd_df1['Final Result'].fillna(0)
df1['sampling_location'] = sd_df1['Installation Name']
df1['DL'] = sd_df1['Limit of Detection']
df1['sampling_date'] = pd.to_datetime(sd_df1['Sample Date'])
df1['sample_id'] = sd_df1['Laboratory Sample ID']
df1['units'] = sd_df1['Final Units']
df1['state'] = sd_df1['State']
df1['analytical_methods'] = sd_df1['Analysis Method']
df1['data_source'] = 'DoD'
df1['source_type'] = 'drinking water'

# %%
df1['is_detected'] = df1['concentration'] != 0

# %%
df1
# Out:
#       sample_id sampling_location data_source  latitude  longitude  \
# 0     573149004     Ellsworth AFB         DoD       NaN        NaN
# 1     573149004     Ellsworth AFB         DoD       NaN        NaN
# 2     573149004     Ellsworth AFB         DoD       NaN        NaN
# 3     573149004     Ellsworth AFB         DoD       NaN        NaN
# 4     573149004     Ellsworth AFB         DoD       NaN        NaN
# ...         ...               ...         ...       ...        ...
# 3307  649663004     Ellsworth AFB         DoD       NaN        NaN
# 3308  649663004     Ellsworth AFB         DoD       NaN        NaN
# 3309  649663004     Ellsworth AFB         DoD       NaN        NaN
# 3310  649663004     Ellsworth AFB         DoD       NaN        NaN
# 3311  649663004     Ellsworth AFB         DoD       NaN        NaN
#
#      sampling_date pws_id water_system_name  population well_type  ...  city  \
# 0       2022-03-13    NaN               NaN         NaN       NaN  ...   NaN
# ...

# %%
df1.to_csv('southdakota_dw.csv')
