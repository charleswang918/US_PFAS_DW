# %%
import os
import pandas as pd
import numpy

# %%
os.getcwd()
# Out:
# '/Users/chuqiwang/Documents/US_PFAS_Project/data_merging_analysis/UCMR3&5'

# %%
# !ls
# Out:
# UCMR3
# UCMR5
# avg_PFAS_concentration_map_ucmr3&5(GU).html
# avg_PFAS_concentration_map_ucmr3&5(GW).html
# avg_PFAS_concentration_map_ucmr3&5(MX).html
# avg_PFAS_concentration_map_ucmr3&5(SW).html
# avg_PFAS_concentration_map_ucmr3&5.html
# cleaning_ucmr3&5.ipynb

# %%
ucmr3_df = pd.read_csv('UCMR3/ucmr3_cleaned.csv', index_col=0)

# %%
ucmr3_df
# Out:
#              sample_id      sampling_location data_source   latitude  \
# 0              3209653              WTP EPTDS       UCMR3 -36.748250
# 1              3209653              WTP EPTDS       UCMR3 -36.748250
# 2              3209653              WTP EPTDS       UCMR3 -36.748250
# 3              3209653              WTP EPTDS       UCMR3 -36.748250
# 4              3209653              WTP EPTDS       UCMR3 -36.748250
# ...                ...                    ...         ...        ...
# 221826  201511140097AM  EPTDS from GUDI Plant       UCMR3  55.982885
# 221827  201511140097AM  EPTDS from GUDI Plant       UCMR3  55.982885
# 221828  201511140097AM  EPTDS from GUDI Plant       UCMR3  55.982885
# 221829  201511140097AM  EPTDS from GUDI Plant       UCMR3  55.982885
# 221830  201511140097AM  EPTDS from GUDI Plant       UCMR3  55.982885
#
#         longitude sampling_date     pws_id                 water_system_name  \
# ...

# %%
ucmr5_df = pd.read_csv('UCMR5/ucmr5_cleaned.csv', index_col=0)

# %%
ucmr5_df
# Out:
#           sample_id                             sampling_location data_source  \
# 0       810-79458-1                   Entry point to Dist. System       UCMR5
# 1       810-79458-1                   Entry point to Dist. System       UCMR5
# 2       810-79458-1                   Entry point to Dist. System       UCMR5
# 3       810-73346-1                   Entry point to Dist. System       UCMR5
# 4       810-79458-1                   Entry point to Dist. System       UCMR5
# ...             ...                                           ...         ...
# 915936      117104R  Facility 930 - Booker Road and Cheyenne Road       UCMR5
# 915937      117104R  Facility 930 - Booker Road and Cheyenne Road       UCMR5
# 915938      117104R  Facility 930 - Booker Road and Cheyenne Road       UCMR5
# 915939      117104R  Facility 930 - Booker Road and Cheyenne Road       UCMR5
# 915940      117104R  Facility 930 - Booker Road and Cheyenne Road       UCMR5
#
# ...

# %%
ucmr_df = pd.concat([ucmr3_df, ucmr5_df])

# %%
ucmr_df.index = range(0, len(ucmr_df))
ucmr_df
# Out:
#         sample_id                             sampling_location data_source  \
# 0         3209653                                     WTP EPTDS       UCMR3
# 1         3209653                                     WTP EPTDS       UCMR3
# 2         3209653                                     WTP EPTDS       UCMR3
# 3         3209653                                     WTP EPTDS       UCMR3
# 4         3209653                                     WTP EPTDS       UCMR3
# ...           ...                                           ...         ...
# 1137767   117104R  Facility 930 - Booker Road and Cheyenne Road       UCMR5
# 1137768   117104R  Facility 930 - Booker Road and Cheyenne Road       UCMR5
# 1137769   117104R  Facility 930 - Booker Road and Cheyenne Road       UCMR5
# 1137770   117104R  Facility 930 - Booker Road and Cheyenne Road       UCMR5
# 1137771   117104R  Facility 930 - Booker Road and Cheyenne Road       UCMR5
#
# ...

# %%
ucmr_df.to_csv('ucmr_df.csv')

# %%
missing_latitude = ucmr_df['latitude'].isna().sum()
missing_longitude = ucmr_df['longitude'].isna().sum()
print(f"Missing latitudes: {missing_latitude}, Missing longitudes: {missing_longitude}")
# Out:
# Missing latitudes: 18859, Missing longitudes: 18859

# %%
from geopy.geocoders import Nominatim

geolocator = Nominatim(user_agent="unique_project_name_12345")
location = geolocator.geocode("American Fork City")
if location:
    print((location.latitude, location.longitude))
else:
    print("Location not found")
# Out:
# (40.3802468, -111.79202012816013)
